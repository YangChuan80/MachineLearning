# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sb

#from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix
#import joblib
#from sklearn.model_selection import ShuffleSplit
#from sklearn.model_selection import KFold
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow import keras

from os import walk

import time
import datetime

# %matplotlib inline

# %%
pathBase = 'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//'
#pathBase = 'E://Chuan//Documents//Database//DICOM//CoroBase//Arrangement//'

theWhole = {}
# theWhole is dictionary containing views (keys) which the values are DICOM files

f = []
f_LCA_Caudal = []
mypath_LCA_Caudal = pathBase + 'LCA_Caudal'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Caudal):
    f.extend(filenames)
for l in f:
    f_LCA_Caudal.append(mypath_LCA_Caudal + '\\' + l) 
    
f = []
f_LCA_Cranial = []
mypath_LCA_Cranial = pathBase + 'LCA_Cranial'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Cranial):
    f.extend(filenames)
for l in f:
    f_LCA_Cranial.append(mypath_LCA_Cranial + '\\' + l) 
    
f = []
f_LCA_Cranial_LAO = []
mypath_LCA_Cranial_LAO = pathBase + 'LCA_Cranial_LAO'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Cranial_LAO):
    f.extend(filenames)
for l in f:
    f_LCA_Cranial_LAO.append(mypath_LCA_Cranial_LAO + '\\' + l) 
    
    
f = []
f_LCA_Cranial_RAO = []
mypath_LCA_Cranial_RAO = pathBase + 'LCA_Cranial_RAO'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Cranial_RAO):
    f.extend(filenames)
for l in f:
    f_LCA_Cranial_RAO.append(mypath_LCA_Cranial_RAO + '\\' + l) 
    
f = []
f_LCA_Spider = []
mypath_LCA_Spider = pathBase + 'LCA_Spider'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Spider):
    f.extend(filenames)
for l in f:
    f_LCA_Spider.append(mypath_LCA_Spider + '\\' + l) 
    
f = []
f_RCA_Cranial = []
mypath_RCA_Cranial = pathBase + 'RCA_Cranial'
for (dirpath, dirnames, filenames) in walk(mypath_RCA_Cranial):
    f.extend(filenames)
for l in f:
    f_RCA_Cranial.append(mypath_RCA_Cranial + '\\' + l) 
    
f = []
f_RCA_LAO = []
mypath_RCA_LAO = pathBase + 'RCA_LAO'
for (dirpath, dirnames, filenames) in walk(mypath_RCA_LAO):
    f.extend(filenames)
for l in f:
    f_RCA_LAO.append(mypath_RCA_LAO + '\\' + l) 
    

theWhole['LCA_Caudal'] = f_LCA_Caudal
theWhole['LCA_Cranial'] = f_LCA_Cranial
theWhole['LCA_Cranial_LAO'] = f_LCA_Cranial_LAO
theWhole['LCA_Cranial_RAO'] = f_LCA_Cranial_RAO
theWhole['LCA_Spider'] = f_LCA_Spider
theWhole['RCA_Cranial'] = f_RCA_Cranial
theWhole['RCA_LAO'] = f_RCA_LAO

# %%
viewConvert = {'LCA_Caudal': 0, 
               'LCA_Cranial': 1,
               'LCA_Cranial_LAO': 2,
               'LCA_Cranial_RAO': 3,
               'LCA_Spider': 4,
               'RCA_Cranial': 5,
               'RCA_LAO': 6}

# %%
theWhole['LCA_Cranial_LAO']
# Out:
# ['I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\04A303A242F04B35BC889915B414E048.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\04A303A242F04B35BC889915B414E048.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\07FFCD52CE914F29B7E4BC877FDE039C.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\07FFCD52CE914F29B7E4BC877FDE039C.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\082257329B3A4223B258DCBAB5C11DEA.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\082257329B3A4223B258DCBAB5C11DEA.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0AFD257E3761428881D7A2FFAC11F8D3.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0AFD257E3761428881D7A2FFAC11F8D3.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0B6CF946BD5641B5B42DD20184E77E70.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0B6CF946BD5641B5B42DD20184E77E70.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0D0D0586A84744E1BABE27844888F92B.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0D0D0586A84744E1BABE27844888F92B.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0F479E5C3A914DF69E5380AE49DA14D9.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0F479E5C3A914DF69E5380AE49DA14D9.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0F9A1CAD61FC430784D340F09C9AAD6E.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\0F9A1CAD61FC430784D340F09C9AAD6E.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\121DB291D1B648C09C69DBADF9019FAE.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\121DB291D1B648C09C69DBADF9019FAE.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\134AE04C0D854DF29660BBB8C56736AA.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\134AE04C0D854DF29660BBB8C56736AA.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\1622DB741E73496CB4D8DF49C1932A74.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\1622DB741E73496CB4D8DF49C1932A74.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\194CFAF43C794FF0803402CC5AC59B95.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\194CFAF43C794FF0803402CC5AC59B95.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\29E9FC95676D438EBDBE74668D97564C.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\29E9FC95676D438EBDBE74668D97564C.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\2AD7FC84B6F741E7A9134DD450751CC3.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\2AD7FC84B6F741E7A9134DD450751CC3.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\2CD37FB5826746B28B826C33E86D2211.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\2CD37FB5826746B28B826C33E86D2211.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\307826D7569D41FE9A402447679397C6.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\307826D7569D41FE9A402447679397C6.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\351C6A9A4FDF4C179141BCA7E0376DEB.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\351C6A9A4FDF4C179141BCA7E0376DEB.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\35CAD359BF2448E79B7527C3179357C1.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\35CAD359BF2448E79B7527C3179357C1.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\367E28FAD6ED467C86D654A09B4FBE02.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\367E28FAD6ED467C86D654A09B4FBE02.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\37F6F6FE7A734A489D8D8BE213D223E2.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\37F6F6FE7A734A489D8D8BE213D223E2.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\3A22735081F845D098CEBBA953F2155F.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\3A22735081F845D098CEBBA953F2155F.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\3A3424A8207C4A21A9CC5BB020B7325C.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\3A3424A8207C4A21A9CC5BB020B7325C.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\3A3BD74C2DF9472FA3F47B7AC37C76B1.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\3A3BD74C2DF9472FA3F47B7AC37C76B1.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\3C3DD6793E7D49D2B14E593D31C5BB27.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\3C3DD6793E7D49D2B14E593D31C5BB27.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\4E3E764F27AA49E884CA24EFD1A360D6.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\4E3E764F27AA49E884CA24EFD1A360D6.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\4F79F087F1F648AAA0188B9A497E26EA.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\4F79F087F1F648AAA0188B9A497E26EA.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\501DBBA082274166837D2B40FA8652E6.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\501DBBA082274166837D2B40FA8652E6.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\50F9FF87DAB74FE8A6439117515C4EA4.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\50F9FF87DAB74FE8A6439117515C4EA4.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\511FAA2BB0934C6E859CA18C95CAACB2.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\511FAA2BB0934C6E859CA18C95CAACB2.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\590079CC525C4D968FAE7C846EBFE38E.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\590079CC525C4D968FAE7C846EBFE38E.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\5BBEC7DCF39E462E86F9F15D7559AF99.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\5BBEC7DCF39E462E86F9F15D7559AF99.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\5E09857D320F4B85B8958632500F33C5.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\5E09857D320F4B85B8958632500F33C5.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\604B86FA649A4598AC7D8137BBCF1E05.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\604B86FA649A4598AC7D8137BBCF1E05.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\63A3F4953D104D35ACB22132C7ABBA85.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\63A3F4953D104D35ACB22132C7ABBA85.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\65B86E7E81A04610A897F2034F07D4F4.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\65B86E7E81A04610A897F2034F07D4F4.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\683A980DF24A46C8AE25C5B07ADC96A2.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\683A980DF24A46C8AE25C5B07ADC96A2.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\698786BE8A20481FB27D07D0D66C5949.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\698786BE8A20481FB27D07D0D66C5949.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\6B7BB9F4BDBC45A6AC7E8CBC0C408762.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\6B7BB9F4BDBC45A6AC7E8CBC0C408762.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\6C65382A7EC24B719CDDCF14492CB0B2.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\6C65382A7EC24B719CDDCF14492CB0B2.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\6E9C88E122524136BDF88E4645D56499.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\6E9C88E122524136BDF88E4645D56499.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\7019A259EE5C46B08C2C96371D1F8648.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\7019A259EE5C46B08C2C96371D1F8648.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\782E64836EE04DCBB88C4AA92E261912.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\782E64836EE04DCBB88C4AA92E261912.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\7F27E208A265422BA55E19BA3796BAB3.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\7F27E208A265422BA55E19BA3796BAB3.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\7FAA14C7465F4E32AF770A1FE833FA4B.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\7FAA14C7465F4E32AF770A1FE833FA4B.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\849873CD2BD04F789A7431E40899BAF6.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\849873CD2BD04F789A7431E40899BAF6.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\88180926C185485FBA8970E368F0A24E.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\88180926C185485FBA8970E368F0A24E.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\889938FA25E547F3B514F6C8A55DB138.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\889938FA25E547F3B514F6C8A55DB138.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\8D8446263AC94349B61C87CC6956C0A7.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\8D8446263AC94349B61C87CC6956C0A7.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\94778EA03C764260A3295B4245D8F572.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\94778EA03C764260A3295B4245D8F572.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\96B4E8C8C1934942A185812A7457D64A.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\96B4E8C8C1934942A185812A7457D64A.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\9895A3DF1B924BF7855FC1C907516738.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\9895A3DF1B924BF7855FC1C907516738.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\996D56873E8F483CBB6E33A1215A3A94.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\996D56873E8F483CBB6E33A1215A3A94.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\9B51FA342BF14212A2646C08BC314ACB.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\9B51FA342BF14212A2646C08BC314ACB.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\9D9C7D11C1E34B8E8CECCDA1D96DF5B6.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\9D9C7D11C1E34B8E8CECCDA1D96DF5B6.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\9E533B40BF834B1EA1F08F3739D344C2.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\9E533B40BF834B1EA1F08F3739D344C2.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\A01ADCEBA0364B2EB8ACAE5541F10264.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\A01ADCEBA0364B2EB8ACAE5541F10264.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\A163D52F96F44D6C87A5387435993B71.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\A163D52F96F44D6C87A5387435993B71.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\A77A9255CB8D44729D604B9749C34CC4.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\A77A9255CB8D44729D604B9749C34CC4.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\A9184710BA0F4D37BEFBF305F7368568.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\A9184710BA0F4D37BEFBF305F7368568.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\AE7E5D90734849AD83DCC49B392B716E.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\AE7E5D90734849AD83DCC49B392B716E.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\B4AAE1D89D8F45F2973794564AC46735.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\B4AAE1D89D8F45F2973794564AC46735.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\D3332CB78449475BA5FA6428A042DC6A.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\D3332CB78449475BA5FA6428A042DC6A.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\D7396581E1974D3F8499E296FA5A4B9E.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\D7396581E1974D3F8499E296FA5A4B9E.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\DDF30044A4A44AC096B0483185752203.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\DDF30044A4A44AC096B0483185752203.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\DEA96359DAE443ECBEEE8CA69F9AADB9.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\DEA96359DAE443ECBEEE8CA69F9AADB9.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E208344057F645EE82407F0735C47036.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E208344057F645EE82407F0735C47036.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E21EE9A6D029460D829814D68764A15E.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E21EE9A6D029460D829814D68764A15E.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E3AE519B69DD46DFAF3B081C18EAFF6D.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E3AE519B69DD46DFAF3B081C18EAFF6D.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E48407D480714103ACA0B0BD58D9FA0F.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E48407D480714103ACA0B0BD58D9FA0F.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E71B3B02429D48218610FC8A93C95E79.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\E71B3B02429D48218610FC8A93C95E79.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F0467C72CD9A4B389462B7D2E67DEDC5.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F0467C72CD9A4B389462B7D2E67DEDC5.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F16EC160E2E94834850FBF98081FCB64.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F16EC160E2E94834850FBF98081FCB64.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F69B724817A84E7F88D75BF7AFC6C42E.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F69B724817A84E7F88D75BF7AFC6C42E.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F88E14A226664545BEDE97C0A2EA9095.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F88E14A226664545BEDE97C0A2EA9095.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F99130010A234653A84F978EA09D270C.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\F99130010A234653A84F978EA09D270C.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FA8F832169F645C0B330860D4A54F4C2.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FA8F832169F645C0B330860D4A54F4C2.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FB48AE4D1EF949FD8B7DDF93DD111945.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FB48AE4D1EF949FD8B7DDF93DD111945.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FD27F5120D954629977AC71C49B47200.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FD27F5120D954629977AC71C49B47200.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FF43A5C1460D48F799A03D4CCED91D40.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FF43A5C1460D48F799A03D4CCED91D40.dcm_average.npy',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FF61A8073D274A36BE18FA2339F0DC75.avi',
#  'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//LCA_Cranial_LAO\\FF61A8073D274A36BE18FA2339F0DC75.dcm_average.npy']

# %%
start = time.time()

array = {}
i = 0

for view in theWhole.keys():
    array[view] = []
    for case in theWhole[view]:
        if case.split('.')[-1] == 'npy':
            arr = np.load(case)
            array[view].append(arr)

end = time.time()
print(end - start)
# Out:
# 1.380753993988037

# %% [markdown]
# ### 2D to 1D

# %%
array_flat = {}

for view in array.keys():
    array_flat[view] = []
    for case in array[view]:
        case_flat = []
        for row in case:
            for column in row:
                case_flat.append(column)            
        array_flat[view].append(case_flat)

# %% [markdown]
# ## Neural Network

# %%
x_sample_list = []
y_sample_list = []

for y, x in array_flat.items():    
    for x_item in x:
        x_sample_list.append(x_item)
        y_sample_list.append(y)

# %%
len(x_sample_list)
# Out:
# 954

# %%
len(x_sample_list[0])
# Out:
# 262144

# %%
512*512
# Out:
# 262144

# %%
len(y_sample_list)
# Out:
# 954

# %%
y_sample_list
# Out:
# ['LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Caudal',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_LAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Cranial_RAO',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'LCA_Spider',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_Cranial',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO',
#  'RCA_LAO']

# %%
y_sample_digital_list = []
for item in y_sample_list:
    y_sample_digital_list.append(viewConvert[item])

# %% [markdown]
# ### Model

# %%
model = Sequential()
model.add(Dense(800, activation='relu', kernel_initializer='he_normal', input_shape=(262144, )))
model.add(Dense(200, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(100, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(80, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(30, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(7, activation='softmax'))

# %% [markdown]
# #### Tensorboard Initilization

# %%
# %load_ext tensorboard
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %% [markdown]
# #### Compile the model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Training

# %%
start = time.time()

X_train = np.array(x_sample_list)
y_train = np.array(y_sample_digital_list)

model.fit(X_train, y_train, epochs=300, batch_size=50, verbose=1, callbacks=[tensorboard_callback])

end = time.time()
# Out:
# Epoch 1/300
#  1/20 [>.............................] - ETA: 0s - loss: 344.1494 - accuracy: 0.1200WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 20/20 [==============================] - 28s 1s/step - loss: 33211.2266 - accuracy: 0.1530
# Epoch 2/300
# 20/20 [==============================] - 27s 1s/step - loss: 21794.8203 - accuracy: 0.1562
# Epoch 3/300
# 20/20 [==============================] - 27s 1s/step - loss: 11279.2363 - accuracy: 0.1562
# Epoch 4/300
# 20/20 [==============================] - 27s 1s/step - loss: 4362.2490 - accuracy: 0.1635
# Epoch 5/300
# 20/20 [==============================] - 27s 1s/step - loss: 2465.3948 - accuracy: 0.2212
# Epoch 6/300
# 20/20 [==============================] - 27s 1s/step - loss: 2009.0338 - accuracy: 0.2694
# Epoch 7/300
# 20/20 [==============================] - 27s 1s/step - loss: 996.8250 - accuracy: 0.3239
# Epoch 8/300
# 20/20 [==============================] - 27s 1s/step - loss: 877.9294 - accuracy: 0.3375
# Epoch 9/300
# 20/20 [==============================] - 27s 1s/step - loss: 634.3675 - accuracy: 0.4203
# Epoch 10/300
# 20/20 [==============================] - 27s 1s/step - loss: 769.9869 - accuracy: 0.4413
# Epoch 11/300
# 20/20 [==============================] - 27s 1s/step - loss: 524.4963 - accuracy: 0.4654
# Epoch 12/300
# 20/20 [==============================] - 27s 1s/step - loss: 603.4063 - accuracy: 0.4078
# Epoch 13/300
# 20/20 [==============================] - 27s 1s/step - loss: 581.9642 - accuracy: 0.4633
# Epoch 14/300
# 20/20 [==============================] - 28s 1s/step - loss: 252.8507 - accuracy: 0.5660
# Epoch 15/300
# 20/20 [==============================] - 27s 1s/step - loss: 267.5699 - accuracy: 0.5702
# Epoch 16/300
# 20/20 [==============================] - 27s 1s/step - loss: 279.8507 - accuracy: 0.5608
# Epoch 17/300
# 20/20 [==============================] - 27s 1s/step - loss: 183.8879 - accuracy: 0.6216
# Epoch 18/300
# 20/20 [==============================] - 28s 1s/step - loss: 603.3734 - accuracy: 0.4832
# Epoch 19/300
# 20/20 [==============================] - 28s 1s/step - loss: 440.2324 - accuracy: 0.4790
# Epoch 20/300
# 20/20 [==============================] - 27s 1s/step - loss: 348.6725 - accuracy: 0.5241
# Epoch 21/300
# 20/20 [==============================] - 27s 1s/step - loss: 218.9040 - accuracy: 0.5692
# Epoch 22/300
# 20/20 [==============================] - 26s 1s/step - loss: 180.6766 - accuracy: 0.6069
# Epoch 23/300
# 20/20 [==============================] - 27s 1s/step - loss: 333.8513 - accuracy: 0.5304
# Epoch 24/300
# 20/20 [==============================] - 27s 1s/step - loss: 263.3373 - accuracy: 0.5828
# Epoch 25/300
# 20/20 [==============================] - 27s 1s/step - loss: 208.2228 - accuracy: 0.5985
# Epoch 26/300
# 20/20 [==============================] - 27s 1s/step - loss: 153.1673 - accuracy: 0.6782
# Epoch 27/300
# 20/20 [==============================] - 27s 1s/step - loss: 76.1218 - accuracy: 0.7872
# Epoch 28/300
# 20/20 [==============================] - 27s 1s/step - loss: 97.5773 - accuracy: 0.7107
# Epoch 29/300
# 20/20 [==============================] - 27s 1s/step - loss: 309.8098 - accuracy: 0.5556
# Epoch 30/300
# 20/20 [==============================] - 27s 1s/step - loss: 265.9887 - accuracy: 0.5671
# Epoch 31/300
# 20/20 [==============================] - 26s 1s/step - loss: 223.6159 - accuracy: 0.6048
# Epoch 32/300
# 20/20 [==============================] - 26s 1s/step - loss: 105.2735 - accuracy: 0.7191
# Epoch 33/300
# 20/20 [==============================] - 26s 1s/step - loss: 98.4998 - accuracy: 0.7170
# Epoch 34/300
# 20/20 [==============================] - 26s 1s/step - loss: 155.9056 - accuracy: 0.6447
# Epoch 35/300
# 20/20 [==============================] - 26s 1s/step - loss: 204.0924 - accuracy: 0.6132
# Epoch 36/300
# 20/20 [==============================] - 26s 1s/step - loss: 151.5946 - accuracy: 0.6562
# Epoch 37/300
# 20/20 [==============================] - 26s 1s/step - loss: 182.6866 - accuracy: 0.6132
# Epoch 38/300
# 20/20 [==============================] - 26s 1s/step - loss: 86.6091 - accuracy: 0.7484
# Epoch 39/300
# 20/20 [==============================] - 26s 1s/step - loss: 103.0317 - accuracy: 0.7055
# Epoch 40/300
# 20/20 [==============================] - 28s 1s/step - loss: 108.5186 - accuracy: 0.7107
# Epoch 41/300
# 20/20 [==============================] - 29s 1s/step - loss: 239.9012 - accuracy: 0.6101
# Epoch 42/300
# 20/20 [==============================] - 27s 1s/step - loss: 98.1779 - accuracy: 0.7254
# Epoch 43/300
# 20/20 [==============================] - 27s 1s/step - loss: 95.0183 - accuracy: 0.6929
# Epoch 44/300
# 20/20 [==============================] - 27s 1s/step - loss: 123.4038 - accuracy: 0.6551
# Epoch 45/300
# 20/20 [==============================] - 27s 1s/step - loss: 193.1661 - accuracy: 0.6268
# Epoch 46/300
# 20/20 [==============================] - 27s 1s/step - loss: 121.5012 - accuracy: 0.7013
# Epoch 47/300
# 20/20 [==============================] - 27s 1s/step - loss: 113.3862 - accuracy: 0.6635
# Epoch 48/300
# 20/20 [==============================] - 27s 1s/step - loss: 107.3163 - accuracy: 0.7002
# Epoch 49/300
# 20/20 [==============================] - 27s 1s/step - loss: 96.6822 - accuracy: 0.7117
# Epoch 50/300
# 20/20 [==============================] - 26s 1s/step - loss: 76.4849 - accuracy: 0.7694
# Epoch 51/300
# 20/20 [==============================] - 26s 1s/step - loss: 94.3378 - accuracy: 0.6792
# Epoch 52/300
# 20/20 [==============================] - 26s 1s/step - loss: 107.8913 - accuracy: 0.6960
# Epoch 53/300
# 20/20 [==============================] - 26s 1s/step - loss: 84.3737 - accuracy: 0.7411
# Epoch 54/300
# 20/20 [==============================] - 26s 1s/step - loss: 58.4929 - accuracy: 0.7746
# Epoch 55/300
# 20/20 [==============================] - 26s 1s/step - loss: 47.4865 - accuracy: 0.8061
# Epoch 56/300
# 20/20 [==============================] - 26s 1s/step - loss: 76.6297 - accuracy: 0.7233
# Epoch 57/300
# 20/20 [==============================] - 26s 1s/step - loss: 117.6479 - accuracy: 0.6562
# Epoch 58/300
# 20/20 [==============================] - 26s 1s/step - loss: 57.7157 - accuracy: 0.7505
# Epoch 59/300
# 20/20 [==============================] - 26s 1s/step - loss: 67.0139 - accuracy: 0.7421
# Epoch 60/300
# 20/20 [==============================] - 28s 1s/step - loss: 77.5086 - accuracy: 0.7170
# Epoch 61/300
# 20/20 [==============================] - 26s 1s/step - loss: 52.6816 - accuracy: 0.7673
# Epoch 62/300
# 20/20 [==============================] - 26s 1s/step - loss: 50.7542 - accuracy: 0.7589
# Epoch 63/300
# 20/20 [==============================] - 26s 1s/step - loss: 40.8767 - accuracy: 0.8082
# Epoch 64/300
# 20/20 [==============================] - 26s 1s/step - loss: 58.7540 - accuracy: 0.7463
# Epoch 65/300
# 20/20 [==============================] - 26s 1s/step - loss: 84.8141 - accuracy: 0.7065
# Epoch 66/300
# 20/20 [==============================] - 26s 1s/step - loss: 51.6867 - accuracy: 0.7610
# Epoch 67/300
# 20/20 [==============================] - 26s 1s/step - loss: 122.6297 - accuracy: 0.6300
# Epoch 68/300
# 20/20 [==============================] - 26s 1s/step - loss: 97.6091 - accuracy: 0.6782
# Epoch 69/300
# 20/20 [==============================] - 26s 1s/step - loss: 107.3430 - accuracy: 0.6782
# Epoch 70/300
# 20/20 [==============================] - 26s 1s/step - loss: 60.9448 - accuracy: 0.7285
# Epoch 71/300
# 20/20 [==============================] - 27s 1s/step - loss: 124.9844 - accuracy: 0.6646
# Epoch 72/300
# 20/20 [==============================] - 26s 1s/step - loss: 41.8595 - accuracy: 0.8145
# Epoch 73/300
# 20/20 [==============================] - 26s 1s/step - loss: 75.1151 - accuracy: 0.6845
# Epoch 74/300
# 20/20 [==============================] - 26s 1s/step - loss: 52.6166 - accuracy: 0.7610
# Epoch 75/300
# 20/20 [==============================] - 26s 1s/step - loss: 112.7650 - accuracy: 0.6813
# Epoch 76/300
# 20/20 [==============================] - 26s 1s/step - loss: 41.3140 - accuracy: 0.8197
# Epoch 77/300
# 20/20 [==============================] - 26s 1s/step - loss: 34.3839 - accuracy: 0.8396
# Epoch 78/300
# 20/20 [==============================] - 26s 1s/step - loss: 36.8404 - accuracy: 0.8312
# Epoch 79/300
# 20/20 [==============================] - 26s 1s/step - loss: 105.3366 - accuracy: 0.6363
# Epoch 80/300
# 20/20 [==============================] - 26s 1s/step - loss: 43.9174 - accuracy: 0.7453
# Epoch 81/300
# 20/20 [==============================] - 26s 1s/step - loss: 69.7184 - accuracy: 0.7170
# Epoch 82/300
# 20/20 [==============================] - 26s 1s/step - loss: 174.3024 - accuracy: 0.5524
# Epoch 83/300
# 20/20 [==============================] - 26s 1s/step - loss: 206.4453 - accuracy: 0.5671
# Epoch 84/300
# 20/20 [==============================] - 26s 1s/step - loss: 118.2195 - accuracy: 0.6394
# Epoch 85/300
# 20/20 [==============================] - 26s 1s/step - loss: 85.1160 - accuracy: 0.7180
# Epoch 86/300
# 20/20 [==============================] - 26s 1s/step - loss: 32.4967 - accuracy: 0.8438
# Epoch 87/300
# 20/20 [==============================] - 26s 1s/step - loss: 33.4725 - accuracy: 0.8103
# Epoch 88/300
# 20/20 [==============================] - 26s 1s/step - loss: 37.3465 - accuracy: 0.8050
# Epoch 89/300
# 20/20 [==============================] - 26s 1s/step - loss: 66.9416 - accuracy: 0.7086
# Epoch 90/300
# 20/20 [==============================] - 26s 1s/step - loss: 77.0528 - accuracy: 0.7243
# Epoch 91/300
# 20/20 [==============================] - 26s 1s/step - loss: 67.8150 - accuracy: 0.7086
# Epoch 92/300
# 20/20 [==============================] - 26s 1s/step - loss: 88.4382 - accuracy: 0.6740
# Epoch 93/300
# 20/20 [==============================] - 26s 1s/step - loss: 63.0088 - accuracy: 0.7023
# Epoch 94/300
# 20/20 [==============================] - 26s 1s/step - loss: 103.5324 - accuracy: 0.6782
# Epoch 95/300
# 20/20 [==============================] - 26s 1s/step - loss: 53.8153 - accuracy: 0.7568
# Epoch 96/300
# 20/20 [==============================] - 26s 1s/step - loss: 26.7563 - accuracy: 0.8323
# Epoch 97/300
# 20/20 [==============================] - 26s 1s/step - loss: 17.9164 - accuracy: 0.8470
# Epoch 98/300
# 20/20 [==============================] - 26s 1s/step - loss: 19.5641 - accuracy: 0.8637
# Epoch 99/300
# 20/20 [==============================] - 26s 1s/step - loss: 32.2207 - accuracy: 0.7893
# Epoch 100/300
# 20/20 [==============================] - 26s 1s/step - loss: 20.4862 - accuracy: 0.8249
# Epoch 101/300
# 20/20 [==============================] - 26s 1s/step - loss: 34.8488 - accuracy: 0.7516
# Epoch 102/300
# 20/20 [==============================] - 26s 1s/step - loss: 28.5349 - accuracy: 0.7788
# Epoch 103/300
# 20/20 [==============================] - 26s 1s/step - loss: 22.5746 - accuracy: 0.8029
# Epoch 104/300
# 20/20 [==============================] - 26s 1s/step - loss: 19.2620 - accuracy: 0.8218
# Epoch 105/300
# 20/20 [==============================] - 26s 1s/step - loss: 20.0198 - accuracy: 0.8333
# Epoch 106/300
# 20/20 [==============================] - 26s 1s/step - loss: 26.9089 - accuracy: 0.8061
# Epoch 107/300
# 20/20 [==============================] - 26s 1s/step - loss: 27.8613 - accuracy: 0.7883
# Epoch 108/300
# 20/20 [==============================] - 26s 1s/step - loss: 27.0227 - accuracy: 0.7830
# Epoch 109/300
# 20/20 [==============================] - 26s 1s/step - loss: 11.9473 - accuracy: 0.8826
# Epoch 110/300
# 20/20 [==============================] - 26s 1s/step - loss: 14.5244 - accuracy: 0.8574
# Epoch 111/300
# 20/20 [==============================] - 26s 1s/step - loss: 19.8079 - accuracy: 0.7883
# Epoch 112/300
# 20/20 [==============================] - 26s 1s/step - loss: 72.5979 - accuracy: 0.5839
# Epoch 113/300
# 20/20 [==============================] - 26s 1s/step - loss: 20.0339 - accuracy: 0.8061
# Epoch 114/300
# 20/20 [==============================] - 26s 1s/step - loss: 48.5481 - accuracy: 0.6908
# Epoch 115/300
# 20/20 [==============================] - 26s 1s/step - loss: 42.2822 - accuracy: 0.6939
# Epoch 116/300
# 20/20 [==============================] - 26s 1s/step - loss: 14.0581 - accuracy: 0.8218
# Epoch 117/300
# 20/20 [==============================] - 26s 1s/step - loss: 14.8144 - accuracy: 0.8155
# Epoch 118/300
# 20/20 [==============================] - 26s 1s/step - loss: 23.8311 - accuracy: 0.7736
# Epoch 119/300
# 20/20 [==============================] - 26s 1s/step - loss: 8.0175 - accuracy: 0.8962
# Epoch 120/300
# 20/20 [==============================] - 26s 1s/step - loss: 17.6130 - accuracy: 0.7987
# Epoch 121/300
# 20/20 [==============================] - 26s 1s/step - loss: 13.8555 - accuracy: 0.8333
# Epoch 122/300
# 20/20 [==============================] - 26s 1s/step - loss: 12.0190 - accuracy: 0.8480
# Epoch 123/300
# 20/20 [==============================] - 26s 1s/step - loss: 17.1662 - accuracy: 0.8050
# Epoch 124/300
# 20/20 [==============================] - 26s 1s/step - loss: 14.5313 - accuracy: 0.8061
# Epoch 125/300
# 20/20 [==============================] - 26s 1s/step - loss: 80.7051 - accuracy: 0.5964
# Epoch 126/300
# 20/20 [==============================] - 26s 1s/step - loss: 93.7383 - accuracy: 0.5818
# Epoch 127/300
# 20/20 [==============================] - 26s 1s/step - loss: 141.6585 - accuracy: 0.5356
# Epoch 128/300
# 20/20 [==============================] - 26s 1s/step - loss: 202.1121 - accuracy: 0.4581
# Epoch 129/300
# 20/20 [==============================] - 26s 1s/step - loss: 211.8512 - accuracy: 0.4717
# Epoch 130/300
# 20/20 [==============================] - 26s 1s/step - loss: 137.8319 - accuracy: 0.5010
# Epoch 131/300
# 20/20 [==============================] - 26s 1s/step - loss: 90.5923 - accuracy: 0.6226
# Epoch 132/300
# 20/20 [==============================] - 26s 1s/step - loss: 78.8841 - accuracy: 0.6457
# Epoch 133/300
# 20/20 [==============================] - 26s 1s/step - loss: 54.4761 - accuracy: 0.6918
# Epoch 134/300
# 20/20 [==============================] - 26s 1s/step - loss: 27.9740 - accuracy: 0.7631
# Epoch 135/300
# 20/20 [==============================] - 26s 1s/step - loss: 47.4138 - accuracy: 0.6719
# Epoch 136/300
# 20/20 [==============================] - 26s 1s/step - loss: 15.7336 - accuracy: 0.7904
# Epoch 137/300
# 20/20 [==============================] - 26s 1s/step - loss: 12.7135 - accuracy: 0.8449
# Epoch 138/300
# 20/20 [==============================] - 26s 1s/step - loss: 8.3902 - accuracy: 0.8711
# Epoch 139/300
# 20/20 [==============================] - 26s 1s/step - loss: 7.6818 - accuracy: 0.8648
# Epoch 140/300
# 20/20 [==============================] - 26s 1s/step - loss: 7.7450 - accuracy: 0.8532
# Epoch 141/300
# 20/20 [==============================] - 26s 1s/step - loss: 13.0564 - accuracy: 0.8124
# Epoch 142/300
# 20/20 [==============================] - 26s 1s/step - loss: 28.4873 - accuracy: 0.7400
# Epoch 143/300
# 20/20 [==============================] - 26s 1s/step - loss: 14.7149 - accuracy: 0.7998
# Epoch 144/300
# 20/20 [==============================] - 26s 1s/step - loss: 11.3740 - accuracy: 0.8291
# Epoch 145/300
# 20/20 [==============================] - 26s 1s/step - loss: 10.5005 - accuracy: 0.8312
# Epoch 146/300
# 20/20 [==============================] - 26s 1s/step - loss: 11.8177 - accuracy: 0.8176
# Epoch 147/300
# 20/20 [==============================] - 26s 1s/step - loss: 15.2330 - accuracy: 0.7998
# Epoch 148/300
# 20/20 [==============================] - 26s 1s/step - loss: 11.3288 - accuracy: 0.8249
# Epoch 149/300
# 20/20 [==============================] - 26s 1s/step - loss: 10.2817 - accuracy: 0.8480
# Epoch 150/300
# 20/20 [==============================] - 26s 1s/step - loss: 9.9829 - accuracy: 0.8249
# Epoch 151/300
# 20/20 [==============================] - 26s 1s/step - loss: 7.2243 - accuracy: 0.8753
# Epoch 152/300
# 20/20 [==============================] - 26s 1s/step - loss: 3.9177 - accuracy: 0.9140
# Epoch 153/300
# 20/20 [==============================] - 26s 1s/step - loss: 11.9291 - accuracy: 0.8029
# Epoch 154/300
# 20/20 [==============================] - 26s 1s/step - loss: 10.2775 - accuracy: 0.8470
# Epoch 155/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.7482 - accuracy: 0.8962
# Epoch 156/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.1461 - accuracy: 0.8931
# Epoch 157/300
# 20/20 [==============================] - 26s 1s/step - loss: 5.5208 - accuracy: 0.8658
# Epoch 158/300
# 20/20 [==============================] - 26s 1s/step - loss: 6.7750 - accuracy: 0.8407
# Epoch 159/300
# 20/20 [==============================] - 26s 1s/step - loss: 5.0463 - accuracy: 0.8826
# Epoch 160/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.5652 - accuracy: 0.8847
# Epoch 161/300
# 20/20 [==============================] - 26s 1s/step - loss: 7.4515 - accuracy: 0.8512
# Epoch 162/300
# 20/20 [==============================] - 26s 1s/step - loss: 10.0767 - accuracy: 0.8155
# Epoch 163/300
# 20/20 [==============================] - 26s 1s/step - loss: 11.0292 - accuracy: 0.7987
# Epoch 164/300
# 20/20 [==============================] - 26s 1s/step - loss: 6.3652 - accuracy: 0.8449
# Epoch 165/300
# 20/20 [==============================] - 26s 1s/step - loss: 12.6555 - accuracy: 0.8008
# Epoch 166/300
# 20/20 [==============================] - 26s 1s/step - loss: 6.5985 - accuracy: 0.8711
# Epoch 167/300
# 20/20 [==============================] - 26s 1s/step - loss: 14.2461 - accuracy: 0.7757
# Epoch 168/300
# 20/20 [==============================] - 26s 1s/step - loss: 5.2553 - accuracy: 0.8784
# Epoch 169/300
# 20/20 [==============================] - 26s 1s/step - loss: 8.9019 - accuracy: 0.8333
# Epoch 170/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.5328 - accuracy: 0.8962
# Epoch 171/300
# 20/20 [==============================] - 26s 1s/step - loss: 5.5878 - accuracy: 0.8637
# Epoch 172/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.4430 - accuracy: 0.8574
# Epoch 173/300
# 20/20 [==============================] - 26s 1s/step - loss: 5.3541 - accuracy: 0.8658
# Epoch 174/300
# 20/20 [==============================] - 26s 1s/step - loss: 3.2735 - accuracy: 0.8994
# Epoch 175/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.6976 - accuracy: 0.8826
# Epoch 176/300
# 20/20 [==============================] - 26s 1s/step - loss: 3.1393 - accuracy: 0.9046
# Epoch 177/300
# 20/20 [==============================] - 26s 1s/step - loss: 3.0449 - accuracy: 0.9004
# Epoch 178/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.3548 - accuracy: 0.8690
# Epoch 179/300
# 20/20 [==============================] - 26s 1s/step - loss: 13.1437 - accuracy: 0.7977
# Epoch 180/300
# 20/20 [==============================] - 26s 1s/step - loss: 7.1340 - accuracy: 0.8438
# Epoch 181/300
# 20/20 [==============================] - 26s 1s/step - loss: 6.8273 - accuracy: 0.8501
# Epoch 182/300
# 20/20 [==============================] - 26s 1s/step - loss: 6.2792 - accuracy: 0.8501
# Epoch 183/300
# 20/20 [==============================] - 26s 1s/step - loss: 8.9672 - accuracy: 0.8459
# Epoch 184/300
# 20/20 [==============================] - 26s 1s/step - loss: 3.9812 - accuracy: 0.9025
# Epoch 185/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.3407 - accuracy: 0.8983
# Epoch 186/300
# 20/20 [==============================] - 26s 1s/step - loss: 5.9540 - accuracy: 0.8491
# Epoch 187/300
# 20/20 [==============================] - 26s 1s/step - loss: 3.7478 - accuracy: 0.8962
# Epoch 188/300
# 20/20 [==============================] - 26s 1s/step - loss: 2.4619 - accuracy: 0.9036
# Epoch 189/300
# 20/20 [==============================] - 27s 1s/step - loss: 4.2775 - accuracy: 0.8784
# Epoch 190/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.1071 - accuracy: 0.8753
# Epoch 191/300
# 20/20 [==============================] - 26s 1s/step - loss: 2.5909 - accuracy: 0.8973
# Epoch 192/300
# 20/20 [==============================] - 26s 1s/step - loss: 2.9297 - accuracy: 0.8962
# Epoch 193/300
# 20/20 [==============================] - 26s 1s/step - loss: 2.1745 - accuracy: 0.9078
# Epoch 194/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.8778 - accuracy: 0.9151
# Epoch 195/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.3261 - accuracy: 0.8595
# Epoch 196/300
# 20/20 [==============================] - 26s 1s/step - loss: 9.0397 - accuracy: 0.8187
# Epoch 197/300
# 20/20 [==============================] - 26s 1s/step - loss: 9.1083 - accuracy: 0.8249
# Epoch 198/300
# 20/20 [==============================] - 26s 1s/step - loss: 21.0314 - accuracy: 0.7170
# Epoch 199/300
# 20/20 [==============================] - 26s 1s/step - loss: 11.3884 - accuracy: 0.8061
# Epoch 200/300
# 20/20 [==============================] - 26s 1s/step - loss: 17.0330 - accuracy: 0.7820
# Epoch 201/300
# 20/20 [==============================] - 26s 1s/step - loss: 7.3222 - accuracy: 0.8501
# Epoch 202/300
# 20/20 [==============================] - 26s 1s/step - loss: 6.4928 - accuracy: 0.8627
# Epoch 203/300
# 20/20 [==============================] - 26s 1s/step - loss: 4.1903 - accuracy: 0.8721
# Epoch 204/300
# 20/20 [==============================] - 26s 1s/step - loss: 3.7754 - accuracy: 0.8899
# Epoch 205/300
# 20/20 [==============================] - 26s 1s/step - loss: 2.9571 - accuracy: 0.9046
# Epoch 206/300
# 20/20 [==============================] - 27s 1s/step - loss: 2.3899 - accuracy: 0.9119
# Epoch 207/300
# 20/20 [==============================] - 26s 1s/step - loss: 2.3598 - accuracy: 0.9214
# Epoch 208/300
# 20/20 [==============================] - 26s 1s/step - loss: 2.0006 - accuracy: 0.9130
# Epoch 209/300
# 20/20 [==============================] - 26s 1s/step - loss: 3.4660 - accuracy: 0.8826
# Epoch 210/300
# 20/20 [==============================] - 26s 1s/step - loss: 6.1497 - accuracy: 0.8291
# Epoch 211/300
# 20/20 [==============================] - 26s 1s/step - loss: 3.1420 - accuracy: 0.8878
# Epoch 212/300
# 20/20 [==============================] - 26s 1s/step - loss: 9.9937 - accuracy: 0.7925
# Epoch 213/300
# 20/20 [==============================] - 26s 1s/step - loss: 8.9482 - accuracy: 0.7369
# Epoch 214/300
# 20/20 [==============================] - 26s 1s/step - loss: 8.1750 - accuracy: 0.7935
# Epoch 215/300
# 20/20 [==============================] - 26s 1s/step - loss: 13.0330 - accuracy: 0.7715
# Epoch 216/300
# 20/20 [==============================] - 26s 1s/step - loss: 7.7508 - accuracy: 0.8155
# Epoch 217/300
# 20/20 [==============================] - 26s 1s/step - loss: 7.9454 - accuracy: 0.8187
# Epoch 218/300
# 20/20 [==============================] - 26s 1s/step - loss: 27.1360 - accuracy: 0.6908
# Epoch 219/300
# 20/20 [==============================] - 26s 1s/step - loss: 7.8366 - accuracy: 0.8029
# Epoch 220/300
# 20/20 [==============================] - 26s 1s/step - loss: 8.0110 - accuracy: 0.8008
# Epoch 221/300
# 20/20 [==============================] - 26s 1s/step - loss: 9.1158 - accuracy: 0.7851
# Epoch 222/300
# 20/20 [==============================] - 26s 1s/step - loss: 25.0572 - accuracy: 0.6604
# Epoch 223/300
# 20/20 [==============================] - 26s 1s/step - loss: 62.3127 - accuracy: 0.5828
# Epoch 224/300
# 20/20 [==============================] - 26s 1s/step - loss: 164.5683 - accuracy: 0.3753
# Epoch 225/300
# 20/20 [==============================] - 26s 1s/step - loss: 90.7273 - accuracy: 0.4591
# Epoch 226/300
# 20/20 [==============================] - 26s 1s/step - loss: 274.8383 - accuracy: 0.2683
# Epoch 227/300
# 20/20 [==============================] - 26s 1s/step - loss: 57.3356 - accuracy: 0.4245
# Epoch 228/300
# 20/20 [==============================] - 26s 1s/step - loss: 24.9057 - accuracy: 0.5314
# Epoch 229/300
# 20/20 [==============================] - 26s 1s/step - loss: 28.5800 - accuracy: 0.4549
# Epoch 230/300
# 20/20 [==============================] - 26s 1s/step - loss: 19.9512 - accuracy: 0.3962
# Epoch 231/300
# 20/20 [==============================] - 26s 1s/step - loss: 2.5007 - accuracy: 0.1887
# Epoch 232/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9974 - accuracy: 0.1646
# Epoch 233/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9340 - accuracy: 0.1667
# Epoch 234/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9294 - accuracy: 0.1667
# Epoch 235/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9268 - accuracy: 0.1667
# Epoch 236/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9248 - accuracy: 0.1667
# Epoch 237/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9241 - accuracy: 0.1667
# Epoch 238/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9232 - accuracy: 0.1667
# Epoch 239/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9226 - accuracy: 0.1709
# Epoch 240/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9220 - accuracy: 0.1761
# Epoch 241/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9218 - accuracy: 0.1761
# Epoch 242/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9216 - accuracy: 0.1761
# Epoch 243/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9213 - accuracy: 0.1761
# Epoch 244/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9210 - accuracy: 0.1761
# Epoch 245/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9210 - accuracy: 0.1761
# Epoch 246/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9210 - accuracy: 0.1761
# Epoch 247/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9207 - accuracy: 0.1761
# Epoch 248/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9208 - accuracy: 0.1761
# Epoch 249/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9206 - accuracy: 0.1761
# Epoch 250/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9206 - accuracy: 0.1761
# Epoch 251/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9205 - accuracy: 0.1761
# Epoch 252/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9204 - accuracy: 0.1761
# Epoch 253/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9204 - accuracy: 0.1761
# Epoch 254/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9205 - accuracy: 0.1761
# Epoch 255/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9203 - accuracy: 0.1761
# Epoch 256/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9202 - accuracy: 0.1761
# Epoch 257/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9205 - accuracy: 0.1761
# Epoch 258/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9225 - accuracy: 0.1751
# Epoch 259/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9225 - accuracy: 0.1751
# Epoch 260/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9222 - accuracy: 0.1751
# Epoch 261/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9223 - accuracy: 0.1751
# Epoch 262/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9222 - accuracy: 0.1751
# Epoch 263/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9222 - accuracy: 0.1751
# Epoch 264/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 265/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9220 - accuracy: 0.1751
# Epoch 266/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 267/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 268/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9220 - accuracy: 0.1751
# Epoch 269/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 270/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9223 - accuracy: 0.1751
# Epoch 271/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 272/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9222 - accuracy: 0.1751
# Epoch 273/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 274/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9220 - accuracy: 0.1751
# Epoch 275/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9219 - accuracy: 0.1751
# Epoch 276/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 277/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 278/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9222 - accuracy: 0.1751
# Epoch 279/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 280/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9223 - accuracy: 0.1751
# Epoch 281/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9223 - accuracy: 0.1751
# Epoch 282/300
# 20/20 [==============================] - 27s 1s/step - loss: 1.9219 - accuracy: 0.1751
# Epoch 283/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9220 - accuracy: 0.1751
# Epoch 284/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 285/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9219 - accuracy: 0.1751
# Epoch 286/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 287/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 288/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9220 - accuracy: 0.1751
# Epoch 289/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9219 - accuracy: 0.1751
# Epoch 290/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 291/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9221 - accuracy: 0.1751
# Epoch 292/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9220 - accuracy: 0.1751
# Epoch 293/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9222 - accuracy: 0.1751
# Epoch 294/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9222 - accuracy: 0.1751
# Epoch 295/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9220 - accuracy: 0.1751
# Epoch 296/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9222 - accuracy: 0.1751
# Epoch 297/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9223 - accuracy: 0.1751
# Epoch 298/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9223 - accuracy: 0.1751
# Epoch 299/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9224 - accuracy: 0.1751
# Epoch 300/300
# 20/20 [==============================] - 26s 1s/step - loss: 1.9223 - accuracy: 0.1751

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 800)               209716000
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               160200
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_3 (Dense)              (None, 80)                8080
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                2430
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 217
# =================================================================
# Total params: 209,907,027
# Trainable params: 209,907,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 22004), started 9:30:29 ago. (Use '!kill 22004' to kill it.)
#       <iframe id="tensorboard-frame-45e9f124f14bd9f3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-45e9f124f14bd9f3");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
print(end - start)

# %% [markdown]
# ### Save the entire model

# %%
model.save('coroLearning_NeralNetwork')
# Out:
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: coroLearning_NeralNetwork\assets

# %% [markdown]
# ### Load the saved model

# %%
new_model = keras.models.load_model('coroLearning_NeralNetwork')

# %%
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 800)               209716000
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               160200
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_3 (Dense)              (None, 80)                8080
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                2430
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 217
# =================================================================
# Total params: 209,907,027
# Trainable params: 209,907,027
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Prediction

# %%
pathBase = 'I://Chuan//Documents//MyData//ProjNormalCAG//CoroBase//Arrangement//test//'
#pathBase = 'I://Chuan//Documents//MyData//NormalCAG//CoroBase//Arrangement//test//'
#pathBase = 'E://Chuan//Documents//Database//DICOM//CoroBase//Arrangement//test//'

theWhole = {}

f = []
f_LCA_Caudal = []
mypath_LCA_Caudal = pathBase + 'LCA_Caudal'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Caudal):
    f.extend(filenames)
for l in f:
    f_LCA_Caudal.append(mypath_LCA_Caudal + '\\' + l) 
    
f = []
f_LCA_Cranial = []
mypath_LCA_Cranial = pathBase + 'LCA_Cranial'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Cranial):
    f.extend(filenames)
for l in f:
    f_LCA_Cranial.append(mypath_LCA_Cranial + '\\' + l) 
    
f = []
f_LCA_Cranial_LAO = []
mypath_LCA_Cranial_LAO = pathBase + 'LCA_Cranial_LAO'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Cranial_LAO):
    f.extend(filenames)
for l in f:
    f_LCA_Cranial_LAO.append(mypath_LCA_Cranial_LAO + '\\' + l) 
    
    
f = []
f_LCA_Cranial_RAO = []
mypath_LCA_Cranial_RAO = pathBase + 'LCA_Cranial_RAO'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Cranial_RAO):
    f.extend(filenames)
for l in f:
    f_LCA_Cranial_RAO.append(mypath_LCA_Cranial_RAO + '\\' + l) 
    
f = []
f_LCA_Spider = []
mypath_LCA_Spider = pathBase + 'LCA_Spider'
for (dirpath, dirnames, filenames) in walk(mypath_LCA_Spider):
    f.extend(filenames)
for l in f:
    f_LCA_Spider.append(mypath_LCA_Spider + '\\' + l) 
    
f = []
f_RCA_Cranial = []
mypath_RCA_Cranial = pathBase + 'RCA_Cranial'
for (dirpath, dirnames, filenames) in walk(mypath_RCA_Cranial):
    f.extend(filenames)
for l in f:
    f_RCA_Cranial.append(mypath_RCA_Cranial + '\\' + l) 
    
f = []
f_RCA_LAO = []
mypath_RCA_LAO = pathBase + 'RCA_LAO'
for (dirpath, dirnames, filenames) in walk(mypath_RCA_LAO):
    f.extend(filenames)
for l in f:
    f_RCA_LAO.append(mypath_RCA_LAO + '\\' + l) 
    

theWhole['LCA_Caudal'] = f_LCA_Caudal
theWhole['LCA_Cranial'] = f_LCA_Cranial
theWhole['LCA_Cranial_LAO'] = f_LCA_Cranial_LAO
theWhole['LCA_Cranial_RAO'] = f_LCA_Cranial_RAO
theWhole['LCA_Spider'] = f_LCA_Spider
theWhole['RCA_Cranial'] = f_RCA_Cranial
theWhole['RCA_LAO'] = f_RCA_LAO

# %%
start = time.time()

array = {}
i = 0

for view in theWhole.keys():
    array[view] = []
    for case in theWhole[view]:
        if case.split('.')[-1] == 'npy':
            arr = np.load(case)
            array[view].append(arr)

end = time.time()
print(end - start)

# %% [markdown]
# ### 2D to 1D

# %%
array_flat = {}

for view in array.keys():
    array_flat[view] = []
    for case in array[view]:
        case_flat = []
        for row in case:
            for column in row:
                case_flat.append(column)            
        array_flat[view].append(case_flat)

# %%
x_test_list = []
y_test_list = []

for y, x in array_flat.items():    
    for x_item in x:
        x_test_list.append(x_item)
        y_test_list.append(y)

# %%
y_test_digital_list = []
for item in y_test_list:
    y_test_digital_list.append(viewConvert[item])

# %%
X_test = np.array(x_test_list)
y_test = np.array(y_test_digital_list)

# %% [markdown]
# ## Performance Measures

# %%
#y_predict = clf.predict(X_test)
#y_test = y_test

loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)

# %%
y_predict = model.predict(X_test)

# %%
y_predict

# %%
y_test

# %% [markdown]
# ### Confusion Matrix (混淆矩阵)

# %%
cm = np.array(confusion_matrix(y_test, y_predict, labels=[0, 1, 2, 3, 4, 5, 6, 7]))
confusion = pd.DataFrame(cm, index=[0, 1, 2, 3, 4, 5, 6, 7],
                        columns=[0, 1, 2, 3, 4, 5, 6, 7])
confusion.to_csv('ConfusionMatrix_NN.csv')
confusion

# %%
print(classification_report(y_test, y_predict))

# %%
plt.figure(figsize=(8, 6))
heat_map = sb.heatmap(confusion, annot=True, 
                      cmap='coolwarm', 
                      xticklabels=confusion.columns, yticklabels=confusion.index, 
                      linewidths=.5, 
                      annot_kws={"size": 20})

# %%
heat_map.figure.savefig("Heatmap_SVM.png", dpi=400)

# %% [markdown]
# ## Save the Model

# %%
c = joblib.dump(clf, 'trained_model.m')
print(c)

# %% [markdown]
# ## Load the Model

# %%
d = joblib.load('trained_model.m')
print(d)

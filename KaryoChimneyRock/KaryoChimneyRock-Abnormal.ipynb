# %% [markdown]
# # A Semi-automatic Classification of Normal Karyotypes based on Support Vector Machine Algorithm

# %% [markdown]
# - **Chuan Yang**, MD, PhD Student
# - Mentor: **Yanyan Zhao**, MD, PhD
# - Shengjing Hospital of China Medical University

# %% [markdown]
# ## Modules

# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sb

from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.externals import joblib
from os import walk

import time

# %matplotlib inline

# %% [markdown]
# ## Samples
# ### File Import

# %%
pathBase = 'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\'
theWhole = {}

f = []
f_01 = []
mypath_01 = pathBase + 'chr_01'
for (dirpath, dirnames, filenames) in walk(mypath_01):
    f.extend(filenames)
for l in f:
    f_01.append(mypath_01 + '\\' + l) 
        
f = []
f_02 = []
mypath_02 = pathBase + 'chr_02'
for (dirpath, dirnames, filenames) in walk(mypath_02):
    f.extend(filenames)
for l in f:
    f_02.append(mypath_02 + '\\' + l)    
        
f = []
f_03 = []
mypath_03 = pathBase + 'chr_03'
for (dirpath, dirnames, filenames) in walk(mypath_03):
    f.extend(filenames)
for l in f:
    f_03.append(mypath_03 + '\\' + l)    
        
f = []
f_04 = []
mypath_04 = pathBase + 'chr_04'
for (dirpath, dirnames, filenames) in walk(mypath_04):
    f.extend(filenames)
for l in f:
    f_04.append(mypath_04 + '\\' + l)    
        
f = []
f_05 = []
mypath_05 = pathBase + 'chr_05'
for (dirpath, dirnames, filenames) in walk(mypath_05):
    f.extend(filenames)
for l in f:
    f_05.append(mypath_05 + '\\' + l)    
        
f = []
f_06 = []
mypath_06 = pathBase + 'chr_06'
for (dirpath, dirnames, filenames) in walk(mypath_06):
    f.extend(filenames)
for l in f:
    f_06.append(mypath_06 + '\\' + l)    
    
f = []
f_07 = []
mypath_07 = pathBase + 'chr_07'
for (dirpath, dirnames, filenames) in walk(mypath_07):
    f.extend(filenames)
for l in f:
    f_07.append(mypath_07 + '\\' + l)    
        
f = []
f_08 = []
mypath_08 = pathBase + 'chr_08'
for (dirpath, dirnames, filenames) in walk(mypath_08):
    f.extend(filenames)
for l in f:
    f_08.append(mypath_08 + '\\' + l)    
        
f = []
f_09 = []
mypath_09 = pathBase + 'chr_09'
for (dirpath, dirnames, filenames) in walk(mypath_09):
    f.extend(filenames)
for l in f:
    f_09.append(mypath_09 + '\\' + l)    
    
f = []
f_10 = []
mypath_10 = pathBase + 'chr_10'
for (dirpath, dirnames, filenames) in walk(mypath_10):
    f.extend(filenames)
for l in f:
    f_10.append(mypath_10 + '\\' + l)    
    
f = []
f_11 = []
mypath_11 = pathBase + 'chr_11'
for (dirpath, dirnames, filenames) in walk(mypath_11):
    f.extend(filenames)
for l in f:
    f_11.append(mypath_11 + '\\' + l)    
    
    
f = []
f_12 = []
mypath_12 = pathBase + 'chr_12'
for (dirpath, dirnames, filenames) in walk(mypath_12):
    f.extend(filenames)
for l in f:
    f_12.append(mypath_12 + '\\' + l)    
    
    
f = []
f_13 = []
mypath_13 = pathBase + 'chr_13'
for (dirpath, dirnames, filenames) in walk(mypath_13):
    f.extend(filenames)
for l in f:
    f_13.append(mypath_13 + '\\' + l)    
    
    
f = []
f_14 = []
mypath_14 = pathBase + 'chr_14'
for (dirpath, dirnames, filenames) in walk(mypath_14):
    f.extend(filenames)
for l in f:
    f_14.append(mypath_14 + '\\' + l)    
    

    
f = []
f_15 = []
mypath_15 = pathBase + 'chr_15'
for (dirpath, dirnames, filenames) in walk(mypath_15):
    f.extend(filenames)
for l in f:
    f_15.append(mypath_15 + '\\' + l)    
    
        
f = []
f_16 = []
mypath_16 = pathBase + 'chr_16'
for (dirpath, dirnames, filenames) in walk(mypath_16):
    f.extend(filenames)
for l in f:
    f_16.append(mypath_16 + '\\' + l)    
    
        
f = []
f_17 = []
mypath_17 = pathBase + 'chr_17'
for (dirpath, dirnames, filenames) in walk(mypath_17):
    f.extend(filenames)
for l in f:
    f_17.append(mypath_17 + '\\' + l)    
    
        
f = []
f_18 = []
mypath_18 = pathBase + 'chr_18'
for (dirpath, dirnames, filenames) in walk(mypath_18):
    f.extend(filenames)
for l in f:
    f_18.append(mypath_18 + '\\' + l)    
    
        
f = []
f_19 = []
mypath_19 = pathBase + 'chr_19'
for (dirpath, dirnames, filenames) in walk(mypath_19):
    f.extend(filenames)
for l in f:
    f_19.append(mypath_19 + '\\' + l)    
    
        
f = []
f_20 = []
mypath_20 = pathBase + 'chr_20'
for (dirpath, dirnames, filenames) in walk(mypath_20):
    f.extend(filenames)
for l in f:
    f_20.append(mypath_20 + '\\' + l)    
   
        
f = []
f_21 = []
mypath_21 = pathBase + 'chr_21'
for (dirpath, dirnames, filenames) in walk(mypath_21):
    f.extend(filenames)
for l in f:
    f_21.append(mypath_21 + '\\' + l)    
   
        
f = []
f_22 = []
mypath_22 = pathBase + 'chr_22'
for (dirpath, dirnames, filenames) in walk(mypath_22):
    f.extend(filenames)
for l in f:
    f_22.append(mypath_22 + '\\' + l)    
   
f = []
f_x = []
mypath_x = pathBase + 'chr_x'
for (dirpath, dirnames, filenames) in walk(mypath_x):
    f.extend(filenames)
for l in f:
    f_x.append(mypath_x + '\\' + l)    
   
f = []
f_y = []
mypath_y = pathBase + 'chr_y'
for (dirpath, dirnames, filenames) in walk(mypath_y):
    f.extend(filenames)
for l in f:
    f_y.append(mypath_y + '\\' + l)  
    
# ///////// Abnormal ones //////////////

f = []
f_18_p11_deletion = []
mypath_18_p11_deletion = pathBase + 'chr_18_p11_deletion'
for (dirpath, dirnames, filenames) in walk(mypath_18_p11_deletion):
    f.extend(filenames)
for l in f:
    f_18_p11_deletion.append(mypath_18_p11_deletion + '\\' + l)  


f = []
f_18_q10_isochromosome = []
mypath_18_q10_isochromosome = pathBase + 'chr_18_q10_isochromosome'
for (dirpath, dirnames, filenames) in walk(mypath_18_q10_isochromosome):
    f.extend(filenames)
for l in f:
    f_18_q10_isochromosome.append(mypath_18_q10_isochromosome + '\\' + l)  
    
# ///////// Abnormal ones //////////////

f = []
f_9_inversion = []
mypath_9_inversion = pathBase + 'chr_9_inversion'
for (dirpath, dirnames, filenames) in walk(mypath_9_inversion):
    f.extend(filenames)
for l in f:
    f_9_inversion.append(mypath_9_inversion + '\\' + l)  
    

f = []
f_5_p14_deletion = []
mypath_5_p14_deletion = pathBase + 'chr_5_p14_deletion'
for (dirpath, dirnames, filenames) in walk(mypath_5_p14_deletion):
    f.extend(filenames)
for l in f:
    f_5_p14_deletion.append(mypath_5_p14_deletion + '\\' + l)  
    

f = []
f_x_isochromosome = []
mypath_x_isochromosome = pathBase + 'chr_x_isochromosome'
for (dirpath, dirnames, filenames) in walk(mypath_x_isochromosome):
    f.extend(filenames)
for l in f:
    f_x_isochromosome.append(mypath_x_isochromosome + '\\' + l)  
    
    
f = []
f_x_p22_cnv = []
mypath_x_p22_cnv = pathBase + 'chr_x_p22_cnv'
for (dirpath, dirnames, filenames) in walk(mypath_x_p22_cnv):
    f.extend(filenames)
for l in f:
    f_x_p22_cnv.append(mypath_x_p22_cnv + '\\' + l)
    
    
f = []
f_x_q21_cnv = []
mypath_x_q21_cnv = pathBase + 'chr_x_q21_cnv'
for (dirpath, dirnames, filenames) in walk(mypath_x_q21_cnv):
    f.extend(filenames)
for l in f:
    f_x_q21_cnv.append(mypath_x_q21_cnv + '\\' + l)  
    
    
f = []
f_x_q22_deletion = []
mypath_x_q22_deletion = pathBase + 'chr_x_q22_deletion'
for (dirpath, dirnames, filenames) in walk(mypath_x_q22_deletion):
    f.extend(filenames)
for l in f:
    f_x_q22_deletion.append(mypath_x_q22_deletion + '\\' + l)      

    
theWhole['chr_01'] = f_01
theWhole['chr_02'] = f_02
theWhole['chr_03'] = f_03
theWhole['chr_04'] = f_04
theWhole['chr_05'] = f_05
theWhole['chr_06'] = f_06
theWhole['chr_07'] = f_07
theWhole['chr_08'] = f_08
theWhole['chr_09'] = f_09
theWhole['chr_10'] = f_10
theWhole['chr_11'] = f_11
theWhole['chr_12'] = f_12
theWhole['chr_13'] = f_13
theWhole['chr_14'] = f_14
theWhole['chr_15'] = f_15
theWhole['chr_16'] = f_16
theWhole['chr_17'] = f_17
theWhole['chr_18'] = f_18
theWhole['chr_19'] = f_19
theWhole['chr_20'] = f_20
theWhole['chr_21'] = f_21
theWhole['chr_22'] = f_22
theWhole['chr_x'] = f_x
theWhole['chr_y'] = f_y

theWhole['chr_18_p11_deletion'] = f_18_p11_deletion
theWhole['chr_18_q10_isochromosome'] = f_18_q10_isochromosome

theWhole['chr_9_inversion'] = f_9_inversion

theWhole['chr_5_p14_deletion'] = f_5_p14_deletion    

theWhole['chr_x_isochromosome'] = f_x_isochromosome
theWhole['chr_x_p22_cnv'] = f_x_p22_cnv
theWhole['chr_x_q21_cnv'] = f_x_q21_cnv
theWhole['chr_x_q22_deletion'] = f_x_q22_deletion

# %%
theWhole['chr_x']
# Out:
# ['C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0003.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0004.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0006.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0008.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0009.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0010.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0011.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0012.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0014.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0016.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0019.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0020.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0023.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0024.X_.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0025.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0026.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0034.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0036.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W17068~A.0039.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w21000~A.0001.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w21000~A.0001.K.jpg.XR.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w21001~A.0008.K.jpg.x.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w21002~A.0024.K.jpg.x.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w21008~A.0008.K.jpg.XL.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w21008~A.0008.K.jpg.XR.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21012~A.0019.K.XL.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21012~A.0019.K.XR.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21022~A.0007.K.jpg.XL.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21022~A.0007.K.jpg.XR.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21025~A.0002.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21027~A.0003.K.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21486~A.0020.K.bmp.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21570~A.0001.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21576~A.0010.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21587~A.0008.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21587~A.0010.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21588~A.0001.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21766~A.0025.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21890~A.0005.K.jpg.XL.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21890~A.0005.K.jpg.XR.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21894~A.0009.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21902~A.0010.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21905~A.0007.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W21906~A.0011.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w22038~A.0017.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w22292~A.0027.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W22451~A.0011.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W22455~A.0002.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W22666-1.0002.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W22670~A.0006.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W22672~A.0004.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0003.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0005.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0007.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0009.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0018.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0025.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0029.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0032.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0033.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0035.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0040.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0042.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-1~A.0046.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W23060-CW190327.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0001.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0004.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0005.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0006.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0007.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0010.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0014.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0023.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0031.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0032.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0033.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0035.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0036.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0037.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0038.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0040.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0041.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0043.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\w25443~A.0047.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0001.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0002.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0006.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0009.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0010.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0012.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0013.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0015.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0016.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0020.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0021.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0022.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0032.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0037.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0038.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0039.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055-1~A.0049.K.jpg.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055~A.0010.X.bmp',
#  'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\chr_x\\W28055~A.0012.X.bmp']

# %% [markdown]
# ## Image Input

# %%
start = time.time()

image = {}
i = 0

for chrNo in theWhole.keys():
    image[chrNo] = []
    for case in theWhole[chrNo]:
        img = Image.open(case)
        image[chrNo].append(img)
    
end = time.time()
print(end - start)
# Out:
# 3.1079108715057373

# %%
image['chr_01'][1]
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=300x300 at 0x18031633A58>

# %% [markdown]
# ## Functions

# %%
def extractData(image):
    x = image.size[0]
    y = image.size[1]
    
    matrix = []
    rgb_matrix = []

    for i in range(x):
        matrix.append([])
        rgb_matrix.append([])
        
        for j in range(y):
            r, g, b = image.getpixel((j, i))            
            value = r * 299.0/1000 + g * 587.0/1000 + b * 114.0/1000
            value = int(value)
            matrix[i].append(value)
            rgb_matrix[i].append((r,g,b))
    return matrix, rgb_matrix

# %%
def imageReconstruct(matrix):
    df = np.array(matrix, dtype=np.uint8)
    img = Image.fromarray(df, 'RGB')
    img.save('image.png')
    return img

# %% [markdown]
# ## Data Extraction from Images

# %%
start = time.time()

data = {}
rgb_data = {}

for chrNo in image.keys():
    data[chrNo] = []; rgb_data[chrNo] = []
    for case in image[chrNo]:
        grey, rgb = extractData(case)
        data[chrNo].append(grey)
        rgb_data[chrNo].append(rgb)
        
end = time.time()
print(end - start)
# Out:
# 256.1426191329956

# %%
imageMatrix = np.array(rgb_data['chr_02'][1])

# %%
img = imageReconstruct(imageMatrix)
img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x180328F4128>

# %% [markdown]
# ## Flat Transformation from 2D to 1D

# %%
data_flat = {}

for chrNo in data.keys():
    data_flat[chrNo] = []
    for case in data[chrNo]:
        case_flat = []
        for row in case:
            for column in row:
                case_flat.append(column)            
        data_flat[chrNo].append(case_flat)

# %% [markdown]
# ## Support Vector Classification

# %%
x_train_list = []
y_train_list = []

for y, x in data_flat.items():    
    for x_item in x:
        x_train_list.append(x_item)
        y_train_list.append(y)

# %% [markdown]
# ### Training

# %%
start = time.time()

X_train = np.array(x_train_list)
y_train = np.array(y_train_list)

clf = svm.SVC(kernel='linear', decision_function_shape='ovo')
clf.fit(X_train, y_train)

end = time.time()

# %%
print(end - start)
# Out:
# 145.57646369934082

# %% [markdown]
# ### Prediction

# %%
print('w = ',clf.coef_)
print('b = ',clf.intercept_)
print('Indices of support vectors = ', clf.support_)
print('Support vectors = ', clf.support_vectors_)
print('Number of support vectors for each class = ', clf.n_support_)
print('Coefficients of the support vector in the decision function = ', np.abs(clf.dual_coef_))
# Out:
# w =  [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    2.16840434e-19  2.16840434e-19]
#  [ 1.35525272e-20  1.35525272e-20  1.35525272e-20 ...  1.35525272e-20
#    1.35525272e-20  1.35525272e-20]
#  [ 6.77626358e-21  6.77626358e-21  6.77626358e-21 ...  6.77626358e-21
#    6.77626358e-21  6.77626358e-21]
#  ...
#  [-6.77626358e-21 -6.77626358e-21 -6.77626358e-21 ... -6.77626358e-21
#   -6.77626358e-21 -6.77626358e-21]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [-6.77626358e-21 -6.77626358e-21 -6.77626358e-21 ... -6.77626358e-21
#    0.00000000e+00  0.00000000e+00]]
# b =  [ -2.59447038   9.71649309   7.82363443   7.3575517   12.15115857
#   15.32670357  12.31317133  13.12274864  14.22508964  12.37071863
#    8.65728198   8.29830326   9.68348651   9.91072787  13.38526824
#   10.24681347  11.70468089   5.56944396   6.82645397  13.22584066
#   12.45679792  12.19422023  12.29029786   3.11427566   8.97473371
#   15.72184715  14.31356234   8.2435713   12.48726578  12.16382935
#   10.20597277   6.21608172   8.76011192   8.38309277  12.54720043
#   13.38641317  12.59259485  11.89619835  12.0871102   12.407053
#   11.07451444  10.23277579  10.56613993  10.13345812  11.0516729
#   10.44034544   9.86667598   5.93946904   5.62503558   8.77906145
#    8.03075715   9.03337747   8.99064419   3.8884616    6.8988868
#   12.77818584  10.18944387   8.29509011   6.73916428   9.61299158
#    8.416163     3.49554527   2.57855845   5.90068275   7.71113374
#    8.81412757   8.70696248   9.64709418   7.7629487    7.73522222
#    6.9135715    8.28585645   8.84573998  11.22711844   9.59839272
#    9.97442812   4.83423676   3.53849941  10.94572576  10.42718254
#    9.58330179  10.43715944   1.39509053   5.65276006   7.6520652
#    5.97177481   6.23915076   8.36909122   7.88072899   8.93939601
#    1.40607273   0.21838707   2.85625181   4.56575556   4.30048126
#    5.62316682   4.07673203   7.74651246   6.33213111   5.94841433
#    5.36485343   5.82694444   5.49766342   4.71179534   2.91733681
#    1.29370251   5.10223952   4.72582432   5.02700405   5.14446329
#   -1.10845913   1.86142586   2.77508286   0.50434858   3.98954273
#    4.08510899   4.03355124   4.58956255   0.8107879    3.71065926
#    7.23412352   6.67676117   7.75872607   6.60743169  11.05772614
#    6.26988781   6.17275971   6.48612305   6.9569496    6.80915499
#    6.3648839    4.42516869   2.89438179   5.80027442   5.40326037
#    5.4913575    5.49153141   2.6265681    2.22797944   6.31490949
#    0.53888994   6.51058361   4.75300683   6.04489489   5.39616816
#    2.25897197   7.79617689   4.87472023   6.66315365   4.66802398
#    6.74641207   6.80358695   7.94239636   8.262815     7.30548231
#    7.16979947   7.10321736   3.71092746   1.50682433   6.59983591
#    6.10699578   6.3449607    6.73794622  -0.58319712   1.64090354
#    3.43229212   0.21392803   4.16812243   3.68331604   3.67248255
#    6.71275321   8.82617316   8.85283829   7.86748326   5.6126725
#    4.62484714   5.50038285   6.3621279    7.27442425   9.30343755
#    8.14904213   7.5313337    4.06320889   1.67653449   8.07726329
#    7.07896227   7.60420728   7.73421962  -2.22960584  -0.53366708
#   12.18551572  -6.11178588   5.43082404   5.13433549   7.14640314
#    7.10740235  -2.50819555   6.53236619   0.89319342   2.97180387
#    6.68537042   8.55056759   8.71077222   8.75677959   6.90555676
#    7.20779907   3.68192215  -0.37202583   7.65863314   5.77590363
#    8.68940252   8.38909808  -3.87474214  -1.61331932  -6.40831021
#   -5.53956943   6.72249728   3.56255358   1.52515953   8.296839
#    4.86156447   2.85688371   1.40733172   4.33366374   5.49016607
#    5.99476476   9.80971738   7.63218997   5.42320693   2.47138461
#   -0.43135237   6.94408365   5.48445903   6.4823025    6.36470001
#   -3.112552    -2.68431476  -8.59125072  -7.57412971   2.9013789
#    3.3952448    5.71953919   5.81021493  -2.54078261  -1.10189795
#    2.45656064   4.26461198   3.6090593    6.39058025   5.08406881
#    4.26993848   2.34900201  -0.50542468   5.3482862    4.40398424
#    5.30420638   5.60121922  -4.25404343  -1.38981229  -6.12976731
#   -8.1441844    1.92366772   3.38279025  -0.30417151   4.14823584
#   -0.04893903   2.26434993   2.69547406   2.54897322   6.2086629
#    5.92284845   2.84310065   1.63351709  -0.73300522   4.49329265
#    3.85777895   4.34332551   4.1794504   -3.3800654   -0.83731484
#   -3.40281315  -9.63818879   0.16886702   4.03921308   2.73672982
#    2.94782576   3.22345606   3.38339683   2.72697836   4.02063818
#    5.74274126   2.92673608   1.87014486  -0.90066662   3.58845573
#    2.93490754   3.95270288   3.8519817   -6.06584425  -0.97008463
#   -3.91870426  -5.33885159   0.17100145   2.60531022   1.39200602
#    3.32790694   0.85889106   1.84617202   1.16579353   1.25734707
#    0.65474672   2.14422367  -1.84685999   2.11255772   1.86003659
#    4.49039092   3.84411403  -6.25402382  -2.41888966  -3.64449135
#   -4.90945435  -2.35572693   1.71104893  -1.51608858   2.84004025
#    8.19118195   0.43641902   0.96256206  -0.9770785    0.87598867
#   -2.53908799   2.67594564   2.01445046   4.88907434   5.43444506
#   -5.23731235  -3.10467446  -4.55247367  -6.04153509  -3.46807028
#    1.34290132  -2.47358634   3.28446134   1.27856632   1.76698008
#   -0.30864319   0.88405987  -2.4974043    3.71179687   3.07762799
#    5.51818811   5.67797635  -5.46813855  -2.51281979  -4.75588839
#   -6.52788948  -2.89901887   1.46163866  -1.95071182   4.11515412
#   -1.12702617   2.32792796  -0.94577342  -3.7865993    9.90318612
#    4.23685949   9.49297409  12.42443351  -4.31212342  -3.10979001
#   -6.82859442 -11.56527757  -4.74850006   2.22162574  -7.08973671
#    3.37291368   0.75917067  -0.51480747  -3.1930161    2.28538775
#    2.89266262   4.16061453   4.1543015   -4.57547159  -2.96581414
#   -5.65547909  -8.94392316  -3.44660199   1.45732616  -3.87052214
#    1.86799306   3.17096421  -3.32091413   3.78659624   1.94145402
#    9.11801185  12.00089011  -4.40386812  -2.56078419  -4.76161429
#   -9.80282066  -2.54503794   1.58511936  -2.98806408   4.73062729
#   -2.70383321   1.73444997   1.29554289   3.94684157   3.75998489
#   -3.90697062  -2.40430879  -2.71519377  -4.13104434  -2.66946291
#    1.31920281  -1.98039437   0.04905052   4.00478886   3.66744901
#    4.10738169   3.96395836  -1.46699788  -1.41297471  -0.04636209
#   -3.60427899   1.06687135   3.56386198  -1.36420175   3.00790613
#   -0.43272946   9.45763092  13.55346611  -4.24474991  -3.26299795
#   -5.96155273 -11.1152322   -4.04263949   0.9481299   -5.10228126
#    1.30054502   2.02156418   3.86537333  -3.74005301  -2.63239742
#   -5.35663781  -9.89827238  -3.192066     0.68353764  -4.67421729
#    0.22304799  -6.34764964  -4.38102744  -3.48328878  -5.59059495
#  -10.76093055  -4.24213131  -0.66413382  -4.19824466  -6.3344767
#   -4.34859592  -3.55137287  -5.39863957 -10.95769407  -4.22126201
#   -0.55210411  -4.25442674  -8.81311268   1.3148411    2.2788331
#    0.84021146   3.41316709   3.22108744   2.71429836   4.34689723
#    2.85098802  -2.94227437   2.31951865   3.13350159   2.16473819
#    2.95478871  -9.88017238   7.22696062  13.06115197   4.97544513
#    5.14622595   4.50825457  10.05789681   8.22851257   7.85933262
#    2.4864249   -1.19061803   3.92703899  -3.18739718  -0.37647728
#    3.44318225]
# Indices of support vectors =  [   0    1    3 ... 1533 1534 1535]
# Support vectors =  [[255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  ...
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]]
# Number of support vectors for each class =  [46 44 35 47 61 48 50 54 88 46 45 41 42 49 53 46 44 60  8  8 41 37 24 46
#  10 12 66 29  7  7 23 18]
# Coefficients of the support vector in the decision function =  [[0.00000000e+00 0.00000000e+00 6.98910415e-08 ... 0.00000000e+00
#   0.00000000e+00 2.68080894e-09]
#  [6.01573110e-09 1.18562233e-08 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 5.15525518e-09]
#  [0.00000000e+00 2.76241229e-09 4.26689729e-09 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 1.82385304e-09 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [3.21912861e-09 7.89863945e-09 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.19065498e-09 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 2.88643212e-08]]

# %%
pathBase = 'C:\\Users\\Chuan\\OneDrive\\Dowrun\\Database\\PhD\\KaryoTypes\\Arrangement\\test\\'
theWhole = {}

f = []
f_01 = []
mypath_01 = pathBase + 'chr_01'
for (dirpath, dirnames, filenames) in walk(mypath_01):
    f.extend(filenames)
for l in f:
    f_01.append(mypath_01 + '\\' + l) 
        
f = []
f_02 = []
mypath_02 = pathBase + 'chr_02'
for (dirpath, dirnames, filenames) in walk(mypath_02):
    f.extend(filenames)
for l in f:
    f_02.append(mypath_02 + '\\' + l)    
        
f = []
f_03 = []
mypath_03 = pathBase + 'chr_03'
for (dirpath, dirnames, filenames) in walk(mypath_03):
    f.extend(filenames)
for l in f:
    f_03.append(mypath_03 + '\\' + l)    
        
f = []
f_04 = []
mypath_04 = pathBase + 'chr_04'
for (dirpath, dirnames, filenames) in walk(mypath_04):
    f.extend(filenames)
for l in f:
    f_04.append(mypath_04 + '\\' + l)    
        
f = []
f_05 = []
mypath_05 = pathBase + 'chr_05'
for (dirpath, dirnames, filenames) in walk(mypath_05):
    f.extend(filenames)
for l in f:
    f_05.append(mypath_05 + '\\' + l)    
        
f = []
f_06 = []
mypath_06 = pathBase + 'chr_06'
for (dirpath, dirnames, filenames) in walk(mypath_06):
    f.extend(filenames)
for l in f:
    f_06.append(mypath_06 + '\\' + l)    
    
f = []
f_07 = []
mypath_07 = pathBase + 'chr_07'
for (dirpath, dirnames, filenames) in walk(mypath_07):
    f.extend(filenames)
for l in f:
    f_07.append(mypath_07 + '\\' + l)    
        
f = []
f_08 = []
mypath_08 = pathBase + 'chr_08'
for (dirpath, dirnames, filenames) in walk(mypath_08):
    f.extend(filenames)
for l in f:
    f_08.append(mypath_08 + '\\' + l)    
        
f = []
f_09 = []
mypath_09 = pathBase + 'chr_09'
for (dirpath, dirnames, filenames) in walk(mypath_09):
    f.extend(filenames)
for l in f:
    f_09.append(mypath_09 + '\\' + l)    
    
f = []
f_10 = []
mypath_10 = pathBase + 'chr_10'
for (dirpath, dirnames, filenames) in walk(mypath_10):
    f.extend(filenames)
for l in f:
    f_10.append(mypath_10 + '\\' + l)    
    
f = []
f_11 = []
mypath_11 = pathBase + 'chr_11'
for (dirpath, dirnames, filenames) in walk(mypath_11):
    f.extend(filenames)
for l in f:
    f_11.append(mypath_11 + '\\' + l)    
    
    
f = []
f_12 = []
mypath_12 = pathBase + 'chr_12'
for (dirpath, dirnames, filenames) in walk(mypath_12):
    f.extend(filenames)
for l in f:
    f_12.append(mypath_12 + '\\' + l)    
    
    
f = []
f_13 = []
mypath_13 = pathBase + 'chr_13'
for (dirpath, dirnames, filenames) in walk(mypath_13):
    f.extend(filenames)
for l in f:
    f_13.append(mypath_13 + '\\' + l)    
    
    
f = []
f_14 = []
mypath_14 = pathBase + 'chr_14'
for (dirpath, dirnames, filenames) in walk(mypath_14):
    f.extend(filenames)
for l in f:
    f_14.append(mypath_14 + '\\' + l)    
    

    
f = []
f_15 = []
mypath_15 = pathBase + 'chr_15'
for (dirpath, dirnames, filenames) in walk(mypath_15):
    f.extend(filenames)
for l in f:
    f_15.append(mypath_15 + '\\' + l)    
    
        
f = []
f_16 = []
mypath_16 = pathBase + 'chr_16'
for (dirpath, dirnames, filenames) in walk(mypath_16):
    f.extend(filenames)
for l in f:
    f_16.append(mypath_16 + '\\' + l)    
    
        
f = []
f_17 = []
mypath_17 = pathBase + 'chr_17'
for (dirpath, dirnames, filenames) in walk(mypath_17):
    f.extend(filenames)
for l in f:
    f_17.append(mypath_17 + '\\' + l)    
    
        
f = []
f_18 = []
mypath_18 = pathBase + 'chr_18'
for (dirpath, dirnames, filenames) in walk(mypath_18):
    f.extend(filenames)
for l in f:
    f_18.append(mypath_18 + '\\' + l)    
    
        
f = []
f_19 = []
mypath_19 = pathBase + 'chr_19'
for (dirpath, dirnames, filenames) in walk(mypath_19):
    f.extend(filenames)
for l in f:
    f_19.append(mypath_19 + '\\' + l)    
    
        
f = []
f_20 = []
mypath_20 = pathBase + 'chr_20'
for (dirpath, dirnames, filenames) in walk(mypath_20):
    f.extend(filenames)
for l in f:
    f_20.append(mypath_20 + '\\' + l)    
   
        
f = []
f_21 = []
mypath_21 = pathBase + 'chr_21'
for (dirpath, dirnames, filenames) in walk(mypath_21):
    f.extend(filenames)
for l in f:
    f_21.append(mypath_21 + '\\' + l)    
   
        
f = []
f_22 = []
mypath_22 = pathBase + 'chr_22'
for (dirpath, dirnames, filenames) in walk(mypath_22):
    f.extend(filenames)
for l in f:
    f_22.append(mypath_22 + '\\' + l)    
   
f = []
f_x = []
mypath_x = pathBase + 'chr_x'
for (dirpath, dirnames, filenames) in walk(mypath_x):
    f.extend(filenames)
for l in f:
    f_x.append(mypath_x + '\\' + l)    
   
f = []
f_y = []
mypath_y = pathBase + 'chr_y'
for (dirpath, dirnames, filenames) in walk(mypath_y):
    f.extend(filenames)
for l in f:
    f_y.append(mypath_y + '\\' + l)  
    

# ///////// Abnormal ones //////////////

f = []
f_18_p11_deletion = []
mypath_18_p11_deletion = pathBase + 'chr_18_p11_deletion'
for (dirpath, dirnames, filenames) in walk(mypath_18_p11_deletion):
    f.extend(filenames)
for l in f:
    f_18_p11_deletion.append(mypath_18_p11_deletion + '\\' + l)  


f = []
f_18_q10_isochromosome = []
mypath_18_q10_isochromosome = pathBase + 'chr_18_q10_isochromosome'
for (dirpath, dirnames, filenames) in walk(mypath_18_q10_isochromosome):
    f.extend(filenames)
for l in f:
    f_18_q10_isochromosome.append(mypath_18_q10_isochromosome + '\\' + l)  
    


f = []
f_9_inversion = []
mypath_9_inversion = pathBase + 'chr_9_inversion'
for (dirpath, dirnames, filenames) in walk(mypath_9_inversion):
    f.extend(filenames)
for l in f:
    f_9_inversion.append(mypath_9_inversion + '\\' + l)  
    

f = []
f_5_p14_deletion = []
mypath_5_p14_deletion = pathBase + 'chr_5_p14_deletion'
for (dirpath, dirnames, filenames) in walk(mypath_5_p14_deletion):
    f.extend(filenames)
for l in f:
    f_5_p14_deletion.append(mypath_5_p14_deletion + '\\' + l)  
    

f = []
f_x_isochromosome = []
mypath_x_isochromosome = pathBase + 'chr_x_isochromosome'
for (dirpath, dirnames, filenames) in walk(mypath_x_isochromosome):
    f.extend(filenames)
for l in f:
    f_x_isochromosome.append(mypath_x_isochromosome + '\\' + l)  
    
    
f = []
f_x_p22_cnv = []
mypath_x_p22_cnv = pathBase + 'chr_x_p22_cnv'
for (dirpath, dirnames, filenames) in walk(mypath_x_p22_cnv):
    f.extend(filenames)
for l in f:
    f_x_p22_cnv.append(mypath_x_p22_cnv + '\\' + l)
    
    
f = []
f_x_q21_cnv = []
mypath_x_q21_cnv = pathBase + 'chr_x_q21_cnv'
for (dirpath, dirnames, filenames) in walk(mypath_x_q21_cnv):
    f.extend(filenames)
for l in f:
    f_x_q21_cnv.append(mypath_x_q21_cnv + '\\' + l)  
    
    
f = []
f_x_q22_deletion = []
mypath_x_q22_deletion = pathBase + 'chr_x_q22_deletion'
for (dirpath, dirnames, filenames) in walk(mypath_x_q22_deletion):
    f.extend(filenames)
for l in f:
    f_x_q22_deletion.append(mypath_x_q22_deletion + '\\' + l)      

    
theWhole['chr_01'] = f_01
theWhole['chr_02'] = f_02
theWhole['chr_03'] = f_03
theWhole['chr_04'] = f_04
theWhole['chr_05'] = f_05
theWhole['chr_06'] = f_06
theWhole['chr_07'] = f_07
theWhole['chr_08'] = f_08
theWhole['chr_09'] = f_09
theWhole['chr_10'] = f_10
theWhole['chr_11'] = f_11
theWhole['chr_12'] = f_12
theWhole['chr_13'] = f_13
theWhole['chr_14'] = f_14
theWhole['chr_15'] = f_15
theWhole['chr_16'] = f_16
theWhole['chr_17'] = f_17
theWhole['chr_18'] = f_18
theWhole['chr_19'] = f_19
theWhole['chr_20'] = f_20
theWhole['chr_21'] = f_21
theWhole['chr_22'] = f_22
theWhole['chr_x'] = f_x
theWhole['chr_y'] = f_y

theWhole['chr_18_p11_deletion'] = f_18_p11_deletion
theWhole['chr_18_q10_isochromosome'] = f_18_q10_isochromosome

theWhole['chr_9_inversion'] = f_9_inversion

theWhole['chr_5_p14_deletion'] = f_5_p14_deletion    

theWhole['chr_x_isochromosome'] = f_x_isochromosome
theWhole['chr_x_p22_cnv'] = f_x_p22_cnv
theWhole['chr_x_q21_cnv'] = f_x_q21_cnv
theWhole['chr_x_q22_deletion'] = f_x_q22_deletion

# %%
start = time.time()

image = {}
i = 0

for chrNo in theWhole.keys():
    image[chrNo] = []
    for case in theWhole[chrNo]:
        img = Image.open(case)
        image[chrNo].append(img)
    
end = time.time()
print(end - start)
# Out:
# 3.5407984256744385

# %% [markdown]
# ### Data Extraction

# %%
start = time.time()

data = {}
rgb_data = {}

for chrNo in image.keys():
    data[chrNo] = []; rgb_data[chrNo] = []
    for case in image[chrNo]:
        grey, rgb = extractData(case)
        data[chrNo].append(grey)
        rgb_data[chrNo].append(rgb)
        
end = time.time()
print(end - start)
# Out:
# 61.67334961891174

# %% [markdown]
# ### 2D to 1D

# %%
data_flat = {}

for chrNo in data.keys():
    data_flat[chrNo] = []
    for case in data[chrNo]:
        case_flat = []
        for row in case:
            for column in row:
                case_flat.append(column)            
        data_flat[chrNo].append(case_flat)

# %%
x_test_list = []
y_test_list = []

for y, x in data_flat.items():    
    for x_item in x:
        x_test_list.append(x_item)
        y_test_list.append(y)

# %%
X_test = np.array(x_test_list)
y_test = np.array(y_test_list)

# %% [markdown]
# ## Performance Measures

# %%
y_predict = clf.predict(X_test)
y_test = y_test

# %%
y_predict
# Out:
# array(['chr_01', 'chr_01', 'chr_01', 'chr_01', 'chr_01', 'chr_01',
#        'chr_01', 'chr_02', 'chr_01', 'chr_01', 'chr_01', 'chr_02',
#        'chr_02', 'chr_02', 'chr_02', 'chr_02', 'chr_02', 'chr_02',
#        'chr_02', 'chr_02', 'chr_03', 'chr_03', 'chr_03', 'chr_03',
#        'chr_03', 'chr_03', 'chr_02', 'chr_03', 'chr_03', 'chr_03',
#        'chr_05', 'chr_04', 'chr_04', 'chr_04', 'chr_04',
#        'chr_x_isochromosome', 'chr_04', 'chr_04', 'chr_04', 'chr_04',
#        'chr_05', 'chr_05', 'chr_05', 'chr_05', 'chr_05', 'chr_05',
#        'chr_05', 'chr_05', 'chr_05', 'chr_05', 'chr_06', 'chr_06',
#        'chr_06', 'chr_06', 'chr_06', 'chr_06', 'chr_06', 'chr_06',
#        'chr_06', 'chr_06', 'chr_07', 'chr_07', 'chr_07', 'chr_07',
#        'chr_07', 'chr_07', 'chr_07', 'chr_07', 'chr_07', 'chr_07',
#        'chr_08', 'chr_08', 'chr_08', 'chr_08', 'chr_08', 'chr_08',
#        'chr_08', 'chr_08', 'chr_08', 'chr_08', 'chr_x', 'chr_09', 'chr_x',
#        'chr_10', 'chr_09', 'chr_07', 'chr_08', 'chr_09', 'chr_x',
#        'chr_09', 'chr_10', 'chr_10', 'chr_05', 'chr_10', 'chr_10',
#        'chr_10', 'chr_10', 'chr_10', 'chr_10', 'chr_10', 'chr_11',
#        'chr_11', 'chr_11', 'chr_11', 'chr_11', 'chr_11', 'chr_12',
#        'chr_11', 'chr_11', 'chr_11', 'chr_12', 'chr_12', 'chr_12',
#        'chr_12', 'chr_12', 'chr_17', 'chr_12', 'chr_12', 'chr_12',
#        'chr_12', 'chr_15', 'chr_15', 'chr_13', 'chr_13', 'chr_14',
#        'chr_13', 'chr_13', 'chr_13', 'chr_13', 'chr_13', 'chr_15',
#        'chr_14', 'chr_14', 'chr_13', 'chr_15', 'chr_14', 'chr_14',
#        'chr_14', 'chr_15', 'chr_15', 'chr_16', 'chr_15', 'chr_15',
#        'chr_14', 'chr_14', 'chr_14', 'chr_15', 'chr_15', 'chr_15',
#        'chr_15', 'chr_16', 'chr_16', 'chr_10', 'chr_16', 'chr_16',
#        'chr_16', 'chr_16', 'chr_16', 'chr_16', 'chr_16', 'chr_17',
#        'chr_17', 'chr_17', 'chr_17', 'chr_17', 'chr_17', 'chr_17',
#        'chr_17', 'chr_17', 'chr_20', 'chr_18', 'chr_18', 'chr_18',
#        'chr_18', 'chr_18', 'chr_18', 'chr_18', 'chr_16', 'chr_18',
#        'chr_18', 'chr_19', 'chr_19', 'chr_19', 'chr_19', 'chr_19',
#        'chr_19', 'chr_19', 'chr_19', 'chr_19', 'chr_19', 'chr_20',
#        'chr_20', 'chr_20', 'chr_20', 'chr_20', 'chr_20', 'chr_20',
#        'chr_20', 'chr_20', 'chr_20', 'chr_21', 'chr_21', 'chr_21',
#        'chr_21', 'chr_21', 'chr_21', 'chr_21', 'chr_21', 'chr_21',
#        'chr_21', 'chr_21', 'chr_21', 'chr_22', 'chr_22', 'chr_22',
#        'chr_22', 'chr_22', 'chr_22', 'chr_22', 'chr_22', 'chr_x', 'chr_x',
#        'chr_x', 'chr_x', 'chr_x', 'chr_09', 'chr_x_p22_cnv', 'chr_x',
#        'chr_11', 'chr_09', 'chr_y', 'chr_21', 'chr_22', 'chr_18', 'chr_y',
#        'chr_22', 'chr_18', 'chr_21', 'chr_y', 'chr_y', 'chr_y',
#        'chr_18_p11_deletion', 'chr_18', 'chr_14', 'chr_18_p11_deletion',
#        'chr_18_p11_deletion', 'chr_18_p11_deletion',
#        'chr_18_p11_deletion', 'chr_18_p11_deletion',
#        'chr_18_p11_deletion', 'chr_18_q10_isochromosome',
#        'chr_18_q10_isochromosome', 'chr_18_q10_isochromosome',
#        'chr_18_q10_isochromosome', 'chr_07', 'chr_18_q10_isochromosome',
#        'chr_18_q10_isochromosome', 'chr_18_q10_isochromosome',
#        'chr_18_q10_isochromosome', 'chr_9_inversion', 'chr_9_inversion',
#        'chr_9_inversion', 'chr_9_inversion', 'chr_9_inversion',
#        'chr_9_inversion', 'chr_9_inversion', 'chr_07', 'chr_07',
#        'chr_9_inversion', 'chr_5_p14_deletion', 'chr_5_p14_deletion',
#        'chr_04', 'chr_5_p14_deletion', 'chr_05', 'chr_5_p14_deletion',
#        'chr_5_p14_deletion', 'chr_5_p14_deletion', 'chr_03',
#        'chr_x_isochromosome', 'chr_20', 'chr_x_isochromosome', 'chr_07',
#        'chr_x_isochromosome', 'chr_19', 'chr_x_isochromosome',
#        'chr_x_isochromosome', 'chr_01', 'chr_x_isochromosome',
#        'chr_x_p22_cnv', 'chr_x_p22_cnv', 'chr_10', 'chr_x',
#        'chr_x_p22_cnv', 'chr_x', 'chr_x_p22_cnv', 'chr_x_q21_cnv',
#        'chr_x_q21_cnv', 'chr_x_q21_cnv', 'chr_x_q21_cnv', 'chr_x_q21_cnv',
#        'chr_x_q21_cnv', 'chr_x_q21_cnv', 'chr_x_q21_cnv', 'chr_x_q21_cnv',
#        'chr_x_q21_cnv', 'chr_x_q22_deletion', 'chr_10',
#        'chr_x_q22_deletion', 'chr_20', 'chr_x_q22_deletion',
#        'chr_x_q22_deletion', 'chr_08', 'chr_x', 'chr_x_q22_deletion',
#        'chr_x_q22_deletion'], dtype='<U24')

# %%
y_test
# Out:
# array(['chr_01', 'chr_01', 'chr_01', 'chr_01', 'chr_01', 'chr_01',
#        'chr_01', 'chr_01', 'chr_01', 'chr_01', 'chr_02', 'chr_02',
#        'chr_02', 'chr_02', 'chr_02', 'chr_02', 'chr_02', 'chr_02',
#        'chr_02', 'chr_02', 'chr_03', 'chr_03', 'chr_03', 'chr_03',
#        'chr_03', 'chr_03', 'chr_03', 'chr_03', 'chr_03', 'chr_03',
#        'chr_04', 'chr_04', 'chr_04', 'chr_04', 'chr_04', 'chr_04',
#        'chr_04', 'chr_04', 'chr_04', 'chr_04', 'chr_05', 'chr_05',
#        'chr_05', 'chr_05', 'chr_05', 'chr_05', 'chr_05', 'chr_05',
#        'chr_05', 'chr_05', 'chr_06', 'chr_06', 'chr_06', 'chr_06',
#        'chr_06', 'chr_06', 'chr_06', 'chr_06', 'chr_06', 'chr_06',
#        'chr_07', 'chr_07', 'chr_07', 'chr_07', 'chr_07', 'chr_07',
#        'chr_07', 'chr_07', 'chr_07', 'chr_07', 'chr_08', 'chr_08',
#        'chr_08', 'chr_08', 'chr_08', 'chr_08', 'chr_08', 'chr_08',
#        'chr_08', 'chr_08', 'chr_09', 'chr_09', 'chr_09', 'chr_09',
#        'chr_09', 'chr_09', 'chr_09', 'chr_09', 'chr_09', 'chr_09',
#        'chr_10', 'chr_10', 'chr_10', 'chr_10', 'chr_10', 'chr_10',
#        'chr_10', 'chr_10', 'chr_10', 'chr_10', 'chr_11', 'chr_11',
#        'chr_11', 'chr_11', 'chr_11', 'chr_11', 'chr_11', 'chr_11',
#        'chr_11', 'chr_11', 'chr_12', 'chr_12', 'chr_12', 'chr_12',
#        'chr_12', 'chr_12', 'chr_12', 'chr_12', 'chr_12', 'chr_12',
#        'chr_13', 'chr_13', 'chr_13', 'chr_13', 'chr_13', 'chr_13',
#        'chr_13', 'chr_13', 'chr_13', 'chr_13', 'chr_14', 'chr_14',
#        'chr_14', 'chr_14', 'chr_14', 'chr_14', 'chr_14', 'chr_14',
#        'chr_14', 'chr_14', 'chr_15', 'chr_15', 'chr_15', 'chr_15',
#        'chr_15', 'chr_15', 'chr_15', 'chr_15', 'chr_15', 'chr_15',
#        'chr_16', 'chr_16', 'chr_16', 'chr_16', 'chr_16', 'chr_16',
#        'chr_16', 'chr_16', 'chr_16', 'chr_16', 'chr_17', 'chr_17',
#        'chr_17', 'chr_17', 'chr_17', 'chr_17', 'chr_17', 'chr_17',
#        'chr_17', 'chr_17', 'chr_18', 'chr_18', 'chr_18', 'chr_18',
#        'chr_18', 'chr_18', 'chr_18', 'chr_18', 'chr_18', 'chr_18',
#        'chr_19', 'chr_19', 'chr_19', 'chr_19', 'chr_19', 'chr_19',
#        'chr_19', 'chr_19', 'chr_19', 'chr_19', 'chr_20', 'chr_20',
#        'chr_20', 'chr_20', 'chr_20', 'chr_20', 'chr_20', 'chr_20',
#        'chr_20', 'chr_20', 'chr_21', 'chr_21', 'chr_21', 'chr_21',
#        'chr_21', 'chr_21', 'chr_21', 'chr_21', 'chr_21', 'chr_21',
#        'chr_22', 'chr_22', 'chr_22', 'chr_22', 'chr_22', 'chr_22',
#        'chr_22', 'chr_22', 'chr_22', 'chr_22', 'chr_x', 'chr_x', 'chr_x',
#        'chr_x', 'chr_x', 'chr_x', 'chr_x', 'chr_x', 'chr_x', 'chr_x',
#        'chr_y', 'chr_y', 'chr_y', 'chr_y', 'chr_y', 'chr_y', 'chr_y',
#        'chr_y', 'chr_y', 'chr_y', 'chr_18_p11_deletion',
#        'chr_18_p11_deletion', 'chr_18_p11_deletion',
#        'chr_18_p11_deletion', 'chr_18_p11_deletion',
#        'chr_18_p11_deletion', 'chr_18_p11_deletion',
#        'chr_18_p11_deletion', 'chr_18_p11_deletion',
#        'chr_18_p11_deletion', 'chr_18_q10_isochromosome',
#        'chr_18_q10_isochromosome', 'chr_18_q10_isochromosome',
#        'chr_18_q10_isochromosome', 'chr_18_q10_isochromosome',
#        'chr_18_q10_isochromosome', 'chr_18_q10_isochromosome',
#        'chr_18_q10_isochromosome', 'chr_18_q10_isochromosome',
#        'chr_9_inversion', 'chr_9_inversion', 'chr_9_inversion',
#        'chr_9_inversion', 'chr_9_inversion', 'chr_9_inversion',
#        'chr_9_inversion', 'chr_9_inversion', 'chr_9_inversion',
#        'chr_9_inversion', 'chr_5_p14_deletion', 'chr_5_p14_deletion',
#        'chr_5_p14_deletion', 'chr_5_p14_deletion', 'chr_5_p14_deletion',
#        'chr_5_p14_deletion', 'chr_5_p14_deletion', 'chr_5_p14_deletion',
#        'chr_5_p14_deletion', 'chr_x_isochromosome', 'chr_x_isochromosome',
#        'chr_x_isochromosome', 'chr_x_isochromosome',
#        'chr_x_isochromosome', 'chr_x_isochromosome',
#        'chr_x_isochromosome', 'chr_x_isochromosome',
#        'chr_x_isochromosome', 'chr_x_isochromosome', 'chr_x_p22_cnv',
#        'chr_x_p22_cnv', 'chr_x_p22_cnv', 'chr_x_p22_cnv', 'chr_x_p22_cnv',
#        'chr_x_p22_cnv', 'chr_x_p22_cnv', 'chr_x_q21_cnv', 'chr_x_q21_cnv',
#        'chr_x_q21_cnv', 'chr_x_q21_cnv', 'chr_x_q21_cnv', 'chr_x_q21_cnv',
#        'chr_x_q21_cnv', 'chr_x_q21_cnv', 'chr_x_q21_cnv', 'chr_x_q21_cnv',
#        'chr_x_q22_deletion', 'chr_x_q22_deletion', 'chr_x_q22_deletion',
#        'chr_x_q22_deletion', 'chr_x_q22_deletion', 'chr_x_q22_deletion',
#        'chr_x_q22_deletion', 'chr_x_q22_deletion', 'chr_x_q22_deletion',
#        'chr_x_q22_deletion'], dtype='<U24')

# %% [markdown]
# ### Confusion Matrix (混淆矩阵)

# %%
cm = np.array(confusion_matrix(y_test, y_predict, labels=['chr_01', 'chr_02', 'chr_03', 'chr_04', 'chr_05', 
                                    'chr_06', 'chr_07', 'chr_08', 'chr_09', 'chr_10', 
                                    'chr_11', 'chr_12', 'chr_13', 'chr_14', 'chr_15', 
                                    'chr_16', 'chr_17', 'chr_18', 'chr_19', 'chr_20', 
                                    'chr_21', 'chr_22', 'chr_x', 'chr_y']))
confusion = pd.DataFrame(cm, index=['chr_01', 'chr_02', 'chr_03', 'chr_04', 'chr_05', 
                                    'chr_06', 'chr_07', 'chr_08', 'chr_09', 'chr_10', 
                                    'chr_11', 'chr_12', 'chr_13', 'chr_14', 'chr_15', 
                                    'chr_16', 'chr_17', 'chr_18', 'chr_19', 'chr_20', 
                                    'chr_21', 'chr_22', 'chr_x', 'chr_y'],
                        columns=['Predictive chr_01', 'Predictive chr_02', 'Predictive chr_03', 'Predictive chr_04', 'Predictive chr_05', 
                                    'Predictive chr_06', 'Predictive chr_07', 'Predictive chr_08', 'Predictive chr_09', 'Predictive chr_10', 
                                    'Predictive chr_11', 'Predictive chr_12', 'Predictive chr_13', 'Predictive chr_14', 'Predictive chr_15', 
                                    'Predictive chr_16', 'Predictive chr_17', 'Predictive chr_18', 'Predictive chr_19', 'Predictive chr_20', 
                                    'Predictive chr_21', 'Predictive chr_22', 'Predictive chr_x', 'Predictive chr_y' ,
                               ])
confusion.to_csv('ConfusionMatrix.csv')
confusion
# Out:
#         Predictive chr_01  Predictive chr_02  Predictive chr_03  \
# chr_01                  9                  1                  0
# chr_02                  1                  9                  0
# chr_03                  0                  1                  9
# chr_04                  0                  0                  0
# chr_05                  0                  0                  0
# chr_06                  0                  0                  0
# chr_07                  0                  0                  0
# chr_08                  0                  0                  0
# chr_09                  0                  0                  0
# chr_10                  0                  0                  0
# chr_11                  0                  0                  0
# chr_12                  0                  0                  0
# chr_13                  0                  0                  0
# chr_14                  0                  0                  0
# chr_15                  0                  0                  0
# chr_16                  0                  0                  0
# chr_17                  0                  0                  0
# chr_18                  0                  0                  0
# chr_19                  0                  0                  0
# chr_20                  0                  0                  0
# chr_21                  0                  0                  0
# chr_22                  0                  0                  0
# chr_x                   0                  0                  0
# chr_y                   0                  0                  0
#
#         Predictive chr_04  Predictive chr_05  Predictive chr_06  \
# chr_01                  0                  0                  0
# chr_02                  0                  0                  0
# chr_03                  0                  0                  0
# chr_04                  8                  1                  0
# chr_05                  0                 10                  0
# chr_06                  0                  0                 10
# chr_07                  0                  0                  0
# chr_08                  0                  0                  0
# chr_09                  0                  0                  0
# chr_10                  0                  1                  0
# chr_11                  0                  0                  0
# chr_12                  0                  0                  0
# chr_13                  0                  0                  0
# chr_14                  0                  0                  0
# chr_15                  0                  0                  0
# chr_16                  0                  0                  0
# chr_17                  0                  0                  0
# chr_18                  0                  0                  0
# chr_19                  0                  0                  0
# chr_20                  0                  0                  0
# chr_21                  0                  0                  0
# chr_22                  0                  0                  0
# chr_x                   0                  0                  0
# chr_y                   0                  0                  0
#
#         Predictive chr_07  Predictive chr_08  Predictive chr_09  \
# chr_01                  0                  0                  0
# chr_02                  0                  0                  0
# chr_03                  0                  0                  0
# chr_04                  0                  0                  0
# chr_05                  0                  0                  0
# chr_06                  0                  0                  0
# chr_07                 10                  0                  0
# chr_08                  0                 10                  0
# chr_09                  1                  1                  4
# chr_10                  0                  0                  0
# chr_11                  0                  0                  0
# chr_12                  0                  0                  0
# chr_13                  0                  0                  0
# chr_14                  0                  0                  0
# chr_15                  0                  0                  0
# chr_16                  0                  0                  0
# chr_17                  0                  0                  0
# chr_18                  0                  0                  0
# chr_19                  0                  0                  0
# chr_20                  0                  0                  0
# chr_21                  0                  0                  0
# chr_22                  0                  0                  0
# chr_x                   0                  0                  2
# chr_y                   0                  0                  0
#
#         Predictive chr_10  ...  Predictive chr_15  Predictive chr_16  \
# chr_01                  0  ...                  0                  0
# chr_02                  0  ...                  0                  0
# chr_03                  0  ...                  0                  0
# chr_04                  0  ...                  0                  0
# chr_05                  0  ...                  0                  0
# chr_06                  0  ...                  0                  0
# chr_07                  0  ...                  0                  0
# chr_08                  0  ...                  0                  0
# chr_09                  1  ...                  0                  0
# chr_10                  9  ...                  0                  0
# chr_11                  0  ...                  0                  0
# chr_12                  0  ...                  0                  0
# chr_13                  0  ...                  2                  0
# chr_14                  0  ...                  4                  0
# chr_15                  0  ...                  6                  1
# chr_16                  1  ...                  0                  9
# chr_17                  0  ...                  0                  0
# chr_18                  0  ...                  0                  1
# chr_19                  0  ...                  0                  0
# chr_20                  0  ...                  0                  0
# chr_21                  0  ...                  0                  0
# chr_22                  0  ...                  0                  0
# chr_x                   0  ...                  0                  0
# chr_y                   0  ...                  0                  0
#
#         Predictive chr_17  Predictive chr_18  Predictive chr_19  \
# chr_01                  0                  0                  0
# chr_02                  0                  0                  0
# chr_03                  0                  0                  0
# chr_04                  0                  0                  0
# chr_05                  0                  0                  0
# chr_06                  0                  0                  0
# chr_07                  0                  0                  0
# chr_08                  0                  0                  0
# chr_09                  0                  0                  0
# chr_10                  0                  0                  0
# chr_11                  0                  0                  0
# chr_12                  1                  0                  0
# chr_13                  0                  0                  0
# chr_14                  0                  0                  0
# chr_15                  0                  0                  0
# chr_16                  0                  0                  0
# chr_17                  9                  0                  0
# chr_18                  0                  9                  0
# chr_19                  0                  0                 10
# chr_20                  0                  0                  0
# chr_21                  0                  0                  0
# chr_22                  0                  0                  0
# chr_x                   0                  0                  0
# chr_y                   0                  2                  0
#
#         Predictive chr_20  Predictive chr_21  Predictive chr_22  \
# chr_01                  0                  0                  0
# chr_02                  0                  0                  0
# chr_03                  0                  0                  0
# chr_04                  0                  0                  0
# chr_05                  0                  0                  0
# chr_06                  0                  0                  0
# chr_07                  0                  0                  0
# chr_08                  0                  0                  0
# chr_09                  0                  0                  0
# chr_10                  0                  0                  0
# chr_11                  0                  0                  0
# chr_12                  0                  0                  0
# chr_13                  0                  0                  0
# chr_14                  0                  0                  0
# chr_15                  0                  0                  0
# chr_16                  0                  0                  0
# chr_17                  1                  0                  0
# chr_18                  0                  0                  0
# chr_19                  0                  0                  0
# chr_20                 10                  0                  0
# chr_21                  0                 10                  0
# chr_22                  0                  2                  8
# chr_x                   0                  0                  0
# chr_y                   0                  2                  2
#
#         Predictive chr_x  Predictive chr_y
# chr_01                 0                 0
# chr_02                 0                 0
# chr_03                 0                 0
# chr_04                 0                 0
# chr_05                 0                 0
# chr_06                 0                 0
# chr_07                 0                 0
# chr_08                 0                 0
# chr_09                 3                 0
# chr_10                 0                 0
# chr_11                 0                 0
# chr_12                 0                 0
# chr_13                 0                 0
# chr_14                 0                 0
# chr_15                 0                 0
# chr_16                 0                 0
# chr_17                 0                 0
# chr_18                 0                 0
# chr_19                 0                 0
# chr_20                 0                 0
# chr_21                 0                 0
# chr_22                 0                 0
# chr_x                  6                 0
# chr_y                  0                 4
#
# [24 rows x 24 columns]

# %%
print(classification_report(y_test, y_predict))
# Out:
#                           precision    recall  f1-score   support
#
#                   chr_01       0.82      0.90      0.86        10
#                   chr_02       0.82      0.90      0.86        10
#                   chr_03       0.90      0.90      0.90        10
#                   chr_04       0.89      0.80      0.84        10
#                   chr_05       0.77      1.00      0.87        10
#                   chr_06       1.00      1.00      1.00        10
#                   chr_07       0.67      1.00      0.80        10
#                   chr_08       0.83      1.00      0.91        10
#                   chr_09       0.67      0.40      0.50        10
#                   chr_10       0.69      0.90      0.78        10
#                   chr_11       0.90      0.90      0.90        10
#                   chr_12       0.90      0.90      0.90        10
#                   chr_13       0.88      0.70      0.78        10
#                   chr_14       0.50      0.50      0.50        10
#                   chr_15       0.50      0.60      0.55        10
#                   chr_16       0.82      0.90      0.86        10
#                   chr_17       0.90      0.90      0.90        10
#                   chr_18       0.75      0.90      0.82        10
#      chr_18_p11_deletion       1.00      0.70      0.82        10
# chr_18_q10_isochromosome       1.00      0.89      0.94         9
#                   chr_19       0.91      1.00      0.95        10
#                   chr_20       0.77      1.00      0.87        10
#                   chr_21       0.71      1.00      0.83        10
#                   chr_22       0.80      0.80      0.80        10
#       chr_5_p14_deletion       1.00      0.67      0.80         9
#          chr_9_inversion       1.00      0.80      0.89        10
#                    chr_x       0.50      0.60      0.55        10
#      chr_x_isochromosome       0.86      0.60      0.71        10
#            chr_x_p22_cnv       0.80      0.57      0.67         7
#            chr_x_q21_cnv       1.00      1.00      1.00        10
#       chr_x_q22_deletion       1.00      0.60      0.75        10
#                    chr_y       0.80      0.40      0.53        10
#
#                micro avg       0.81      0.81      0.81       315
#                macro avg       0.82      0.80      0.80       315
#             weighted avg       0.82      0.81      0.80       315

# %%
import seaborn as sb

# %%
plt.figure(figsize=(20, 16))
heat_map = sb.heatmap(confusion, annot=True, 
                      cmap='coolwarm', 
                      xticklabels=confusion.columns, yticklabels=confusion.index, 
                      linewidths=.5, 
                      annot_kws={"size": 20})

# %% [markdown]
# ## Save the Model

# %%
c = joblib.dump(clf, 'trained_model.m')
print(c)
# Out:
# ['trained_model.m']

# %% [markdown]
# ## Load the Model

# %%
d = joblib.load('trained_model.m')
print(d)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovo', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)
